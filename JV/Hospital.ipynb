# %%
# Dependencies
import pandas as pd
from pathlib import Path
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
# Store filepath in a variable
file = Path("us_hospital_locations.csv")
hospitals_df = pd.read_csv(file)

hospitals_df.head()
# Out:
#               X             Y  FID        ID  \
# 0 -1.331889e+07  4.346975e+06    1   5793230
# 1 -1.322651e+07  4.049626e+06    2  53391362
# 2 -1.315620e+07  4.031978e+06    3  11190023
# 3 -1.317190e+07  4.041752e+06    4  17090028
# 4 -1.313208e+07  4.037270e+06    5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  NOT AVAILABLE
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  NOT AVAILABLE
#
#    ...             VAL_DATE                           WEBSITE       STATE_ID  \
# 0  ...  2014/02/10 00:00:00      http://www.hanfordhealth.com  NOT AVAILABLE
# 1  ...  2014/02/10 00:00:00  http://www.losrobleshospital.com  NOT AVAILABLE
# 2  ...  2014/02/10 00:00:00             http://www.elalax.com  NOT AVAILABLE
# 3  ...  2014/02/10 00:00:00         http://sch-hollywood.com/  NOT AVAILABLE
# 4  ...  2014/02/10 00:00:00      http://www.khbaldwinpark.com  NOT AVAILABLE
#
#                                     ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                              NOT AVAILABLE       6  PROPRIETARY      -999
# 1                              NOT AVAILABLE       6  PROPRIETARY      -999
# 2                              NOT AVAILABLE       6  PROPRIETARY      -999
# 3  HOLLYWOOD COMMUNITY HOSPITAL OF HOLLYWOOD       6  PROPRIETARY      -999
# 4                              NOT AVAILABLE       6  PROPRIETARY      -999
#
#    BEDS         TRAUMA  HELIPAD
# 0    49  NOT AVAILABLE        N
# 1    62  NOT AVAILABLE        N
# 2   127  NOT AVAILABLE        N
# 3   100  NOT AVAILABLE        N
# 4    95  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
hospitals_df.columns
# Out:
# Index(['X', 'Y', 'FID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
# Choosing columns of interest for our project
cleaned_hospitals_df = hospitals_df[['ID','LATITUDE','LONGITUDE','NAME','CITY','STATE','COUNTY','COUNTRY', 'STATUS']]
cleaned_hospitals_df.head()
# Out:
#          ID   LATITUDE   LONGITUDE  \
# 0   5793230  36.336159 -119.645667
# 1  53391362  34.154939 -118.815736
# 2  11190023  34.023647 -118.184165
# 3  17090028  34.096391 -118.325235
# 4  23691706  34.063039 -117.967438
#
#                                                 NAME             CITY STATE  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL          HANFORD    CA
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...  WESTLAKE VILAGE    CA
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL      LOS ANGELES    CA
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD        HOLLYWOOD    CA
# 4                      KINDRED HOSPITAL BALDWIN PARK     BALDWIN PARK    CA
#
#         COUNTY COUNTRY  STATUS
# 0        KINGS     USA  CLOSED
# 1      VENTURA     USA    OPEN
# 2  LOS ANGELES     USA    OPEN
# 3  LOS ANGELES     USA    OPEN
# 4  LOS ANGELES     USA    OPEN

# %%
cleaned_hospitals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         7596 non-null   int64
#  1   LATITUDE   7596 non-null   float64
#  2   LONGITUDE  7596 non-null   float64
#  3   NAME       7596 non-null   object
#  4   CITY       7596 non-null   object
#  5   STATE      7596 non-null   object
#  6   COUNTY     7596 non-null   object
#  7   COUNTRY    7596 non-null   object
#  8   STATUS     7596 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 534.2+ KB

# %%
# Check for NULL values in the 'COUNTY' column
null_county_values = cleaned_hospitals_df.loc[cleaned_hospitals_df['COUNTY'].isnull()]

# Display the rows with NULL values, if any.
print(null_county_values)
# Out:
# Empty DataFrame
# Columns: [ID, LATITUDE, LONGITUDE, NAME, CITY, STATE, COUNTY, COUNTRY, STATUS]
# Index: []

# %%
# Removing Hospitals with a STATUS of "CLOSED".
filtered_hospitals_df = cleaned_hospitals_df[cleaned_hospitals_df['STATUS'] != 'CLOSED']
filtered_hospitals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7277 entries, 1 to 7595
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         7277 non-null   int64
#  1   LATITUDE   7277 non-null   float64
#  2   LONGITUDE  7277 non-null   float64
#  3   NAME       7277 non-null   object
#  4   CITY       7277 non-null   object
#  5   STATE      7277 non-null   object
#  6   COUNTY     7277 non-null   object
#  7   COUNTRY    7277 non-null   object
#  8   STATUS     7277 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 568.5+ KB

# %%
filtered_hospitals_df.head()
# Out:
#          ID   LATITUDE   LONGITUDE  \
# 1  53391362  34.154939 -118.815736
# 2  11190023  34.023647 -118.184165
# 3  17090028  34.096391 -118.325235
# 4  23691706  34.063039 -117.967438
# 5  25190712  33.859707 -118.148403
#
#                                                 NAME             CITY STATE  \
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...  WESTLAKE VILAGE    CA
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL      LOS ANGELES    CA
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD        HOLLYWOOD    CA
# 4                      KINDRED HOSPITAL BALDWIN PARK     BALDWIN PARK    CA
# 5                   LAKEWOOD REGIONAL MEDICAL CENTER         LAKEWOOD    CA
#
#         COUNTY COUNTRY STATUS
# 1      VENTURA     USA   OPEN
# 2  LOS ANGELES     USA   OPEN
# 3  LOS ANGELES     USA   OPEN
# 4  LOS ANGELES     USA   OPEN
# 5  LOS ANGELES     USA   OPEN

# %%
# Initialize an empty list to store dictionaries
hospital_list = []

# Iterate over the DataFrame rows
for index, row in filtered_hospitals_df.iterrows():
    hospital_dict = {'name': row['NAME'], 'info': row.drop('NAME').to_dict()}
    hospital_list.append(hospital_dict)

# Display the list of dictionaries
pp.pprint(hospital_list)
# Out:
# [   {   'info': {   'CITY': 'WESTLAKE VILAGE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'VENTURA',
#                     'ID': 53391362,
#                     'LATITUDE': 34.1549388720001,
#                     'LONGITUDE': -118.815736391,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CAMPUS'},
#     {   'info': {   'CITY': 'LOS ANGELES',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 11190023,
#                     'LATITUDE': 34.023647302,
#                     'LONGITUDE': -118.184164805,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'EAST LOS ANGELES DOCTORS HOSPITAL'},
#     {   'info': {   'CITY': 'HOLLYWOOD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 17090028,
#                     'LATITUDE': 34.0963913570001,
#                     'LONGITUDE': -118.325234871,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'},
#     {   'info': {   'CITY': 'BALDWIN PARK',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 23691706,
#                     'LATITUDE': 34.063038932,
#                     'LONGITUDE': -117.967437788,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KINDRED HOSPITAL BALDWIN PARK'},
#     {   'info': {   'CITY': 'LAKEWOOD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 25190712,
#                     'LATITUDE': 33.8597066200001,
#                     'LONGITUDE': -118.148402965,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'LAKEWOOD REGIONAL MEDICAL CENTER'},
#     {   'info': {   'CITY': 'MONROVIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 30791016,
#                     'LATITUDE': 34.1487586590001,
#                     'LONGITUDE': -117.992667657,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'MONROVIA MEMORIAL HOSPITAL'},
#     {   'info': {   'CITY': 'MONTEREY PARK',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 30891754,
#                     'LATITUDE': 34.0494660590001,
#                     'LONGITUDE': -118.138262231,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'MONTEREY PARK HOSPITAL'},
#     {   'info': {   'CITY': 'TORRANCE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 47090505,
#                     'LATITUDE': 33.823914464,
#                     'LONGITUDE': -118.356096947,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'STAR VIEW ADOLESCENT - P H F'},
#     {   'info': {   'CITY': 'CORONA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'RIVERSIDE',
#                     'ID': 9092879,
#                     'LATITUDE': 33.8580833070001,
#                     'LONGITUDE': -117.553858035,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'CORONA REGIONAL MEDICAL CENTER-MAGNOLIA'},
#     {   'info': {   'CITY': 'ALTURAS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MODOC',
#                     'ID': 30696101,
#                     'LATITUDE': 41.4800562550001,
#                     'LONGITUDE': -120.545743987,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'MODOC MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SALINAS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MONTEREY',
#                     'ID': 38593901,
#                     'LATITUDE': 36.659030456,
#                     'LONGITUDE': -121.645983804,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SALINAS VALLEY MEMORIAL HOSPITAL'},
#     {   'info': {   'CITY': 'ORANGE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ORANGE',
#                     'ID': 15992866,
#                     'LATITUDE': 33.7827271730001,
#                     'LONGITUDE': -117.833891865,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "HEALTHBRIDGE CHILDREN'S HOSPITAL-ORANGE"},
#     {   'info': {   'CITY': 'TUSTIN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ORANGE',
#                     'ID': 16192680,
#                     'LATITUDE': 33.7474607400001,
#                     'LONGITUDE': -117.831055631,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'HEALTHSOUTH TUSTIN REHABILITATION HOSPITAL'},
#     {   'info': {   'CITY': 'BREA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ORANGE',
#                     'ID': 23792621,
#                     'LATITUDE': 33.934495886,
#                     'LONGITUDE': -117.893948792,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KINDRED HOSPITAL BREA'},
#     {   'info': {   'CITY': 'WESTMINSTER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ORANGE',
#                     'ID': 24392683,
#                     'LATITUDE': 33.7635332090001,
#                     'LONGITUDE': -117.995255963,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KINDRED HOSPITAL WESTMINSTER'},
#     {   'info': {   'CITY': 'VISALIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TULARE',
#                     'ID': 22093277,
#                     'LATITUDE': 36.320843946,
#                     'LONGITUDE': -119.348234528,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAWEAH DELTA MENTAL HEALTH HOSPITAL D/P APH'},
#     {   'info': {   'CITY': 'NEW IBERIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'IBERIA',
#                     'ID': 5870563,
#                     'LATITUDE': 30.006906977,
#                     'LONGITUDE': -91.794523853,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'DAUTERIVE HOSPITAL'},
#     {   'info': {   'CITY': 'CROCKETT',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'HOUSTON',
#                     'ID': 13177954,
#                     'LATITUDE': 31.32360364,
#                     'LONGITUDE': -95.4388993059999,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'CROCKETT MEDICAL CENTER'},
#     {   'info': {   'CITY': 'PINEVILLE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'RAPIDES',
#                     'ID': 4671360,
#                     'LATITUDE': 31.3273789420001,
#                     'LONGITUDE': -92.4401351129999,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'CENTRAL LOUISIANA STATE HOSPITAL'},
#     {   'info': {   'CITY': 'BERNICE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'UNION',
#                     'ID': 15671222,
#                     'LATITUDE': 32.8239916700001,
#                     'LONGITUDE': -92.656648681,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'REEVES MEMORIAL MEDICAL CENTER'},
#     {   'info': {   'CITY': 'FARMERVILLE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'UNION',
#                     'ID': 16971241,
#                     'LATITUDE': 32.776127934,
#                     'LONGITUDE': -92.4056258479999,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'SERENITY SPRINGS SPECIALTY HOSPITAL'},
#     {   'info': {   'CITY': 'VIDALIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CONCORDIA',
#                     'ID': 15371373,
#                     'LATITUDE': 31.5611748630001,
#                     'LONGITUDE': -91.4260669829999,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'RIVERBRIDGE SPECIALTY HOSPITAL'},
#     {   'info': {   'CITY': 'COLUMBIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CALDWELL',
#                     'ID': 5371418,
#                     'LATITUDE': 32.0600399510001,
#                     'LONGITUDE': -92.099137669,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'CITIZENS MEDICAL CENTER'},
#     {   'info': {   'CITY': 'LONG BEACH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 70990806,
#                     'LATITUDE': 33.8070928700001,
#                     'LONGITUDE': -118.193389929,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'COLLEGE MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SAN LEANDRO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ALAMEDA',
#                     'ID': 71794577,
#                     'LATITUDE': 37.706406198,
#                     'LONGITUDE': -122.164654518,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FOUNDATION HOSPITAL - SAN LEANDRO'},
#     {   'info': {   'CITY': 'PARAMOUNT',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 72590723,
#                     'LATITUDE': 33.8846318610001,
#                     'LONGITUDE': -118.162267066,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KINDRED HOSPITAL PARAMOUNT'},
#     {   'info': {   'CITY': 'NORWALK',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 73790650,
#                     'LATITUDE': 33.928031349,
#                     'LONGITUDE': -118.067989672,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'DEPARTMENT OF STATE HOSPITAL-METROPOLITAN'},
#     {   'info': {   'CITY': 'PINCKNEYVILLE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'PERRY',
#                     'ID': 196162274,
#                     'LATITUDE': 38.084846,
#                     'LONGITUDE': -89.3491079999999,
#                     'STATE': 'IL',
#                     'STATUS': 'OPEN'},
#         'name': 'PINCKNEYVILLE COMMUNITY HOSPITAL'},
#     {   'info': {   'CITY': 'SAVANNAH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CHATHAM',
#                     'ID': 85531419,
#                     'LATITUDE': 31.985430321,
#                     'LONGITUDE': -81.154556369,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': "ST JOSEPH'S HOSPITAL - SAVANNAH"},
#     {   'info': {   'CITY': 'ROME',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'FLOYD',
#                     'ID': 86630165,
#                     'LATITUDE': 34.259713445,
#                     'LONGITUDE': -85.1802396319999,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'KINDRED HOSPITAL ROME'},
#     {   'info': {   'CITY': 'THOMASTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'UPSON',
#                     'ID': 87130286,
#                     'LATITUDE': 32.886297701,
#                     'LONGITUDE': -84.3365069879999,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'UPSON REGIONAL MEDICAL CENTER'},
#     {   'info': {   'CITY': 'AMERICUS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SUMTER',
#                     'ID': 87531719,
#                     'LATITUDE': 32.0669623380001,
#                     'LONGITUDE': -84.2560501999999,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'PHOEBE SUMTER MEDICAL CENTER'},
#     {   'info': {   'CITY': 'WARM SPRINGS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MERIWETHER',
#                     'ID': 87931830,
#                     'LATITUDE': 32.887980741,
#                     'LONGITUDE': -84.6923449,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'ROOSEVELT WARM SPRINGS LTAC HOSPITAL'},
#     {   'info': {   'CITY': 'NEWNAN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'COWETA',
#                     'ID': 90030265,
#                     'LATITUDE': 33.3848346460001,
#                     'LONGITUDE': -84.757746692,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'SOUTHEASTERN REGIONAL MEDICAL CENTER'},
#     {   'info': {   'CITY': 'CAROLINA',
#                     'COUNTRY': 'PRI',
#                     'COUNTY': 'METRO',
#                     'ID': 196500984,
#                     'LATITUDE': 18.3804430000001,
#                     'LONGITUDE': -65.95579,
#                     'STATE': 'PR',
#                     'STATUS': 'OPEN'},
#         'name': 'DOCTORS CENTER HOSPITAL SANFERNANDO DE CAROLINA'},
#     {   'info': {   'CITY': 'GREEN BAY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BROWN',
#                     'ID': 2054311,
#                     'LATITUDE': 44.522712261,
#                     'LONGITUDE': -87.924827084,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'BROWN CTY COMMUNITY TREATMENT CENTER'},
#     {   'info': {   'CITY': 'WAUWATOSA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MILWAUKEE',
#                     'ID': 151253226,
#                     'LATITUDE': 43.0358121520001,
#                     'LONGITUDE': -88.037265823,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'WHEATON FRANCISCAN WI HEART SPINE AND ORTHO'},
#     {   'info': {   'CITY': 'BAYAMON',
#                     'COUNTRY': 'PRI',
#                     'COUNTY': 'BAYAMON',
#                     'ID': 196600956,
#                     'LATITUDE': 18.3676556610001,
#                     'LONGITUDE': -66.154391259,
#                     'STATE': 'PR',
#                     'STATUS': 'OPEN'},
#         'name': 'HOSPITAL PSIQUIATRICO DE NINOS YADOLESCENTES'},
#     {   'info': {   'CITY': 'ALEXANDRIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'RAPIDES',
#                     'ID': 159171301,
#                     'LATITUDE': 31.252191558,
#                     'LONGITUDE': -92.481987814,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'COMPASS BEHAVIORAL CENTER OF ALEXANDRIA'},
#     {   'info': {   'CITY': 'RACELAND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LAFOURCHE',
#                     'ID': 163570394,
#                     'LATITUDE': 29.7026714240001,
#                     'LONGITUDE': -90.565253898,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'OCSHNER ST. ANNE GENERAL HOSPITAL'},
#     {   'info': {   'CITY': 'JACKSON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'EAST FELICIANA',
#                     'ID': 164970748,
#                     'LATITUDE': 30.832635688,
#                     'LONGITUDE': -91.210660488,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'FELICIANA FORENSIC FACILITY'},
#     {   'info': {   'CITY': 'GRETNA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'JEFFERSON',
#                     'ID': 160970056,
#                     'LATITUDE': 29.865979474,
#                     'LONGITUDE': -90.03069185,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'UNITED MEDICAL HEALTHWEST-NEW ORLEANS'},
#     {   'info': {   'CITY': 'RIPON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'FOND DU LAC',
#                     'ID': 152354971,
#                     'LATITUDE': 43.8343760920001,
#                     'LONGITUDE': -88.817751529,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'RIPON MEDICAL CENTER'},
#     {   'info': {   'CITY': 'PROVIDENCE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'PROVIDENCE',
#                     'ID': 13402908,
#                     'LATITUDE': 41.8321390840001,
#                     'LONGITUDE': -71.4331495449999,
#                     'STATE': 'RI',
#                     'STATUS': 'OPEN'},
#         'name': 'VA MEDICAL CENTER - PROVIDENCE'},
#     {   'info': {   'CITY': 'TOMAH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MONROE',
#                     'ID': 15954660,
#                     'LATITUDE': 44.00308068,
#                     'LONGITUDE': -90.493319014,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'TOMAH VA MEDICAL CENTER'},
#     {   'info': {   'CITY': 'MERRILL',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LINCOLN',
#                     'ID': 5854452,
#                     'LATITUDE': 45.1756325370001,
#                     'LONGITUDE': -89.681831276,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'ASCENSION GOOD SAMARITAN HLTH CTR'},
#     {   'info': {   'CITY': 'REDDING',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SHASTA',
#                     'ID': 58796001,
#                     'LATITUDE': 40.586595392,
#                     'LONGITUDE': -122.411974107,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'RESTPADD PSYCHIATRIC HEALTH FACILITY'},
#     {   'info': {   'CITY': 'LOMPOC',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SANTA BARBARA',
#                     'ID': 59093436,
#                     'LATITUDE': 34.6353716090001,
#                     'LONGITUDE': -120.452188325,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'THE CHAMPION CENTER'},
#     {   'info': {   'CITY': 'ONTARIO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN BERNARDINO',
#                     'ID': 21891761,
#                     'LATITUDE': 34.0320795600001,
#                     'LONGITUDE': -117.60859933,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP ONTARIO MEDICAL CENTER CAMPUS'},
#     {   'info': {   'CITY': 'LOMA LINDA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN BERNARDINO',
#                     'ID': 25692354,
#                     'LATITUDE': 34.047305635,
#                     'LONGITUDE': -117.251636776,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'LOMA LINDA UNIV. MED. CENTER EAST CAMPUS HOSPITAL'},
#     {   'info': {   'CITY': 'SAN BERNARDINO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN BERNARDINO',
#                     'ID': 44792404,
#                     'LATITUDE': 34.1346723570001,
#                     'LONGITUDE': -117.277019975,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'ST. BERNARDINE MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SAN DIEGO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN DIEGO',
#                     'ID': 20092120,
#                     'LATITUDE': 32.7915625750001,
#                     'LONGITUDE': -117.095159549,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - SAN DIEGO'},
#     {   'info': {   'CITY': 'LA JOLLA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN DIEGO',
#                     'ID': 40992037,
#                     'LATITUDE': 32.896858901,
#                     'LONGITUDE': -117.24287107,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SCRIPPS GREEN HOSPITAL'},
#     {   'info': {   'CITY': 'ENCINITAS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN DIEGO',
#                     'ID': 41092024,
#                     'LATITUDE': 33.0373447760001,
#                     'LONGITUDE': -117.284183383,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SCRIPPS MEMORIAL HOSPITAL - ENCINITAS'},
#     {   'info': {   'CITY': 'SAN DIEGO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN DIEGO',
#                     'ID': 42292123,
#                     'LATITUDE': 32.7982957780001,
#                     'LONGITUDE': -117.154977819,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SHARP MARY BIRCH HOSPITAL FOR WOMEN AND NEWBORNS'},
#     {   'info': {   'CITY': 'SAN DIEGO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN DIEGO',
#                     'ID': 51092103,
#                     'LATITUDE': 32.754770233,
#                     'LONGITUDE': -117.165731384,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'UC SAN DIEGO HEALTH HILLCREST - HILLCREST MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SAN FRANCISCO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN FRANCISCO',
#                     'ID': 4894118,
#                     'LATITUDE': 37.786509197,
#                     'LONGITUDE': -122.456030633,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'CALIFORNIA PACIFIC MED CTR-CALIFORNIA WEST'},
#     {   'info': {   'CITY': 'SAN FRANCISCO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN FRANCISCO',
#                     'ID': 5094115,
#                     'LATITUDE': 37.7907045380001,
#                     'LONGITUDE': -122.431294533,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'CALIFORNIA PACIFIC MED CTR-PACIFIC CAMPUS'},
#     {   'info': {   'CITY': 'SAN FRANCISCO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN FRANCISCO',
#                     'ID': 46594117,
#                     'LATITUDE': 37.77408876,
#                     'LONGITUDE': -122.453751642,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "ST. MARY'S MEDICAL CENTER, SAN FRANCISCO"},
#     {   'info': {   'CITY': 'SANTA ROSA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SONOMA',
#                     'ID': 20595403,
#                     'LATITUDE': 38.471793006,
#                     'LONGITUDE': -122.72706436,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - SANTA ROSA'},
#     {   'info': {   'CITY': 'VALLEJO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SOLANO',
#                     'ID': 19594590,
#                     'LATITUDE': 38.12690208,
#                     'LONGITUDE': -122.248377304,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - REHABILITATION CENTER VALLEJO'},
#     {   'info': {   'CITY': 'WOODLAND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'YOLO',
#                     'ID': 53195695,
#                     'LATITUDE': 38.663925024,
#                     'LONGITUDE': -121.792145249,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'WOODLAND MEMORIAL HOSPITAL'},
#     {   'info': {   'CITY': 'OAKLAND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ALAMEDA',
#                     'ID': 1294609,
#                     'LATITUDE': 37.8201396110001,
#                     'LONGITUDE': -122.26400415,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'ALTA BATES SUMMIT MED CTR-SUMMIT CAMPUS-SUMMIT'},
#     {   'info': {   'CITY': 'SAN LEANDRO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ALAMEDA',
#                     'ID': 39794578,
#                     'LATITUDE': 37.712288347,
#                     'LONGITUDE': -122.143493689,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SAN LEANDRO HOSPITAL'},
#     {   'info': {   'CITY': 'HAYWARD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ALAMEDA',
#                     'ID': 46694545,
#                     'LATITUDE': 37.6334419930001,
#                     'LONGITUDE': -122.087912534,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'ST. ROSE HOSPITAL'},
#     {   'info': {   'CITY': 'STOCKTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN JOAQUIN',
#                     'ID': 45995204,
#                     'LATITUDE': 37.9765963,
#                     'LONGITUDE': -121.291070926,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "ST. JOSEPH'S BEHAVIORAL HEALTH CENTER"},
#     {   'info': {   'CITY': 'STOCKTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN JOAQUIN',
#                     'ID': 46095204,
#                     'LATITUDE': 37.970467188,
#                     'LONGITUDE': -121.288182762,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "ST. JOSEPH'S MEDICAL CENTER OF STOCKTON"},
#     {   'info': {   'CITY': 'GLENDORA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 13291741,
#                     'LATITUDE': 34.132654576,
#                     'LONGITUDE': -117.871259716,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'FOOTHILL PRESBYTERIAN HOSPITAL-JOHNSTON MEMORIAL'},
#     {   'info': {   'CITY': 'GLENDALE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 14791204,
#                     'LATITUDE': 34.128165628,
#                     'LONGITUDE': -118.256643169,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'GLENDALE MEMORIAL HOSPITAL AND HEALTH CENTER'},
#     {   'info': {   'CITY': 'LOS ANGELES',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 19090027,
#                     'LATITUDE': 34.0985736490001,
#                     'LONGITUDE': -118.294175331,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FOUNDATION LOS ANGELES MEDICAL CENTER'},
#     {   'info': {   'CITY': 'PANORAMA CITY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 19391402,
#                     'LATITUDE': 34.2185641940001,
#                     'LONGITUDE': -118.430219294,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER PERMANENTE PANORAMA CITY'},
#     {   'info': {   'CITY': 'TARZANA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 36691356,
#                     'LATITUDE': 34.170393216,
#                     'LONGITUDE': -118.531904059,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'PROVIDENCE TARZANA MEDICAL CENTER'},
#     {   'info': {   'CITY': 'LOS ANGELES',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 42990020,
#                     'LATITUDE': 34.067204777,
#                     'LONGITUDE': -118.286392079,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SHRINERS HOSPITAL FOR CHILDREN - L.A.'},
#     {   'info': {   'CITY': 'HAWAIIAN GARDENS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 50190716,
#                     'LATITUDE': 33.833640007,
#                     'LONGITUDE': -118.079677951,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'GARDENS REGIONAL HOSPITAL AND MEDICAL CENTER'},
#     {   'info': {   'CITY': 'CLEARLAKE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LAKE',
#                     'ID': 45295422,
#                     'LATITUDE': 38.935618855,
#                     'LONGITUDE': -122.620144532,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'ADVENTIST HEALTH CLEARLAKE'},
#     {   'info': {   'CITY': 'MADERA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MADERA',
#                     'ID': 6193638,
#                     'LATITUDE': 36.8840478340001,
#                     'LONGITUDE': -119.800242412,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "VALLEY CHILDREN'S HOSPITAL"},
#     {   'info': {   'CITY': 'RANCHO MIRAGE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'RIVERSIDE',
#                     'ID': 11792270,
#                     'LATITUDE': 33.7633520680001,
#                     'LONGITUDE': -116.406241091,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'EISENHOWER MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SAN JOSE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SANTA CLARA',
#                     'ID': 15295124,
#                     'LATITUDE': 37.252078736,
#                     'LONGITUDE': -121.946576875,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'GOOD SAMARITAN HOSPITAL-SAN JOSE'},
#     {   'info': {   'CITY': 'SANTA CLARA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SANTA CLARA',
#                     'ID': 20495051,
#                     'LATITUDE': 37.3354013750001,
#                     'LONGITUDE': -121.998873047,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - SANTA CLARA'},
#     {   'info': {   'CITY': 'PALO ALTO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SANTA CLARA',
#                     'ID': 27094304,
#                     'LATITUDE': 37.436004575,
#                     'LONGITUDE': -122.175390036,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "LUCILE SALTER PACKARD CHILDREN'S HOSP. AT STANFORD"},
#     {   'info': {   'CITY': 'REDWOOD CITY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN MATEO',
#                     'ID': 19494063,
#                     'LATITUDE': 37.488847836,
#                     'LONGITUDE': -122.223390131,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - REDWOOD CITY'},
#     {   'info': {   'CITY': 'CONCORD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CONTRA COSTA',
#                     'ID': 18094520,
#                     'LATITUDE': 37.9830895790001,
#                     'LONGITUDE': -122.033496796,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'JOHN MUIR MEDICAL CENTER-CONCORD CAMPUS'},
#     {   'info': {   'CITY': 'ANTIOCH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CONTRA COSTA',
#                     'ID': 47794509,
#                     'LATITUDE': 37.9822344500001,
#                     'LONGITUDE': -121.802978505,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SUTTER DELTA MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SACRAMENTO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SACRAMENTO',
#                     'ID': 19995825,
#                     'LATITUDE': 38.601797751,
#                     'LONGITUDE': -121.393144026,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'KAISER FND HOSP - SACRAMENTO'},
#     {   'info': {   'CITY': 'GRASS VALLEY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'NEVADA',
#                     'ID': 43195945,
#                     'LATITUDE': 39.228016294,
#                     'LONGITUDE': -121.047499779,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'SIERRA NEVADA MEMORIAL HOSPITAL'},
#     {   'info': {   'CITY': 'LA PALMA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ORANGE',
#                     'ID': 24690623,
#                     'LATITUDE': 33.8475141810001,
#                     'LONGITUDE': -118.038302332,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'LA PALMA INTERCOMMUNITY HOSPITAL'},
#     {   'info': {   'CITY': 'YUBA CITY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SUTTER',
#                     'ID': 13795991,
#                     'LATITUDE': 39.143106319,
#                     'LONGITUDE': -121.618012022,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'FREMONT MEDICAL CENTER'},
#     {   'info': {   'CITY': 'JASPER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'PICKENS',
#                     'ID': 10230143,
#                     'LATITUDE': 34.4582486800001,
#                     'LONGITUDE': -84.412912891,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'PIEDMONT MOUNTAINSIDE HOSPITAL'},
#     {   'info': {   'CITY': 'ATHENS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CLARKE',
#                     'ID': 15530606,
#                     'LATITUDE': 33.9472213170001,
#                     'LONGITUDE': -83.4052524589999,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'ST MARYS HEALTH CARE SYSTEM'},
#     {   'info': {   'CITY': 'SMYRNA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'COBB',
#                     'ID': 14130080,
#                     'LATITUDE': 33.8564432910001,
#                     'LONGITUDE': -84.51105483,
#                     'STATE': 'GA',
#                     'STATUS': 'OPEN'},
#         'name': 'RIDGEVIEW INSTITUTE'},
#     {   'info': {   'CITY': 'WESTERLY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'WASHINGTON',
#                     'ID': 502891,
#                     'LATITUDE': 41.3621890750001,
#                     'LONGITUDE': -71.825303241,
#                     'STATE': 'RI',
#                     'STATUS': 'OPEN'},
#         'name': 'WESTERLY HOSPITAL'},
#     {   'info': {   'CITY': 'MADISON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'DANE',
#                     'ID': 1553715,
#                     'LATITUDE': 43.0593384640001,
#                     'LONGITUDE': -89.401429215,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'ST MARYS HOSPITAL MADISON'},
#     {   'info': {   'CITY': 'WAUWATOSA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MILWAUKEE',
#                     'ID': 8253213,
#                     'LATITUDE': 43.046765098,
#                     'LONGITUDE': -88.007716433,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'AURORA PSYCHIATRIC HSPTL'},
#     {   'info': {   'CITY': 'MEQUON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'OZAUKEE',
#                     'ID': 9753097,
#                     'LATITUDE': 43.256677929,
#                     'LONGITUDE': -87.926157962,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'COLUMBIA CENTER'},
#     {   'info': {   'CITY': 'BERLIN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'GREEN LAKE',
#                     'ID': 4354923,
#                     'LATITUDE': 43.9784771540001,
#                     'LONGITUDE': -88.94122636,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'THEDACARE MEDICAL CENTER BERLIN'},
#     {   'info': {   'CITY': 'ROGERS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BENTON',
#                     'ID': 63072758,
#                     'LATITUDE': 36.3089928530001,
#                     'LONGITUDE': -94.18297802,
#                     'STATE': 'AR',
#                     'STATUS': 'OPEN'},
#         'name': 'MERCY HOSPITAL ROGERS'},
#     {   'info': {   'CITY': 'SAINT CROIX FALLS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'POLK',
#                     'ID': 10454024,
#                     'LATITUDE': 45.4090324310001,
#                     'LONGITUDE': -92.642578117,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'ST CROIX REG MED CTR'},
#     {   'info': {   'CITY': 'NEW RICHMOND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ST. CROIX',
#                     'ID': 11854017,
#                     'LATITUDE': 45.1177607480001,
#                     'LONGITUDE': -92.555500378,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'WESTFIELDS HOSPITAL'},
#     {   'info': {   'CITY': 'SHEBOYGAN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SHEBOYGAN',
#                     'ID': 12453081,
#                     'LATITUDE': 43.7623479010001,
#                     'LONGITUDE': -87.747537955,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'ST NICHOLAS HOSPITAL'},
#     {   'info': {   'CITY': 'VIROQUA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'VERNON',
#                     'ID': 13154665,
#                     'LATITUDE': 43.551673973,
#                     'LONGITUDE': -90.888391278,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'VERNON MEM HSPTL'},
#     {   'info': {   'CITY': 'DOWNEY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 72390241,
#                     'LATITUDE': 33.9343517980001,
#                     'LONGITUDE': -118.13090396,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'PIH HOSPITAL - DOWNEY'},
#     {   'info': {   'CITY': 'TORRANCE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LOS ANGELES',
#                     'ID': 72790503,
#                     'LATITUDE': 33.8393481160001,
#                     'LONGITUDE': -118.359721519,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': 'PROVIDENCE LITTLE COMPANY OF MARY TRANSITIONAL CARE CENTER'},
#     {   'info': {   'CITY': 'LOMA LINDA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SAN BERNARDINO',
#                     'ID': 58592354,
#                     'LATITUDE': 34.050130832,
#                     'LONGITUDE': -117.264094455,
#                     'STATE': 'CA',
#                     'STATUS': 'OPEN'},
#         'name': "LOMA LINDA UNIVERSITY CHILDREN'S HOSPITAL"},
#     {   'info': {   'CITY': 'OSHKOSH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'WINNEBAGO',
#                     'ID': 15254904,
#                     'LATITUDE': 44.0124207170001,
#                     'LONGITUDE': -88.601045493,
#                     'STATE': 'WI',
#                     'STATUS': 'OPEN'},
#         'name': 'ASCENSION NE WISCONSIN MERCY CAMPUS'},
#     {   'info': {   'CITY': 'WASHINGTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'DISTRICT OF COLUMBIA',
#                     'ID': 75420007,
#                     'LATITUDE': 38.9119585080001,
#                     'LONGITUDE': -77.0752545729999,
#                     'STATE': 'DC',
#                     'STATUS': 'OPEN'},
#         'name': 'MEDSTAR-GEORGETOWN UNIVERSITY MEDICAL CENTER'},
#     {   'info': {   'CITY': 'DADE CITY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'PASCO',
#                     'ID': 31233525,
#                     'LATITUDE': 28.3479628600001,
#                     'LONGITUDE': -82.2007200799999,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'ADVENT HEALTH DADE CITY'},
#     {   'info': {   'CITY': 'DELRAY BEACH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'PALM BEACH',
#                     'ID': 7233484,
#                     'LATITUDE': 26.4371928410001,
#                     'LONGITUDE': -80.127787747,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'DELRAY MEDICAL CENTER'},
#     {   'info': {   'CITY': 'KISSIMMEE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'OSCEOLA',
#                     'ID': 36034758,
#                     'LATITUDE': 28.144780763,
#                     'LONGITUDE': -81.476687855,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'POINCIANA MEDICAL CENTER'},
#     {   'info': {   'CITY': 'ATTLEBORO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BRISTOL',
#                     'ID': 9802703,
#                     'LATITUDE': 41.9240838480001,
#                     'LONGITUDE': -71.3611225619999,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'ARBOUR FULLER HOSPITAL'},
#     {   'info': {   'CITY': 'BROOKLINE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'NORFOLK',
#                     'ID': 9702146,
#                     'LATITUDE': 42.3507795100001,
#                     'LONGITUDE': -71.121242281,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'ARBOUR HUMAN RESOURCE INSTITUTE'},
#     {   'info': {   'CITY': 'MIDDLEBURG',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CLAY',
#                     'ID': 36232068,
#                     'LATITUDE': 30.108762428,
#                     'LONGITUDE': -81.832688692,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': "ASSENCION ST. VINCENT'S MEDICAL CENTER CLAY COUNTY"},
#     {   'info': {   'CITY': 'OCALA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MARION',
#                     'ID': 36334471,
#                     'LATITUDE': 29.165875541,
#                     'LONGITUDE': -82.1623349449999,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'ENCOMPASS HEALTH REHABILITATION HOSPITAL OF OCALA'},
#     {   'info': {   'CITY': 'MANSFIELD CENTER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TOLLAND',
#                     'ID': 3906250,
#                     'LATITUDE': 41.7411039190001,
#                     'LONGITUDE': -72.198011482,
#                     'STATE': 'CT',
#                     'STATUS': 'OPEN'},
#         'name': 'NATCHAUG HOSPITAL, INC.'},
#     {   'info': {   'CITY': 'STUART',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MARTIN',
#                     'ID': 36634997,
#                     'LATITUDE': 27.133437293,
#                     'LONGITUDE': -80.222455815,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'ENCOMPASS HEALTH REHABILITATION HOSPITAL AT MARTIN HEALTH'},
#     {   'info': {   'CITY': 'BOSTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SUFFOLK',
#                     'ID': 10502114,
#                     'LATITUDE': 42.3630925480001,
#                     'LONGITUDE': -71.066301879,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': "SHRINERS' HOSPITAL FOR CHILDREN"},
#     {   'info': {   'CITY': 'BOSTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SUFFOLK',
#                     'ID': 10602129,
#                     'LATITUDE': 42.3785090760001,
#                     'LONGITUDE': -71.049055546,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'SPAULDING REHABILITATION HOSPITAL'},
#     {   'info': {   'CITY': 'FALL RIVER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BRISTOL',
#                     'ID': 11402720,
#                     'LATITUDE': 41.707486913,
#                     'LONGITUDE': -71.145714465,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'DR JOHN C CORRIGAN MENTAL HEALTH CENTER'},
#     {   'info': {   'CITY': 'LYNN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ESSEX',
#                     'ID': 12101904,
#                     'LATITUDE': 42.471620106,
#                     'LONGITUDE': -70.956760931,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'BAY RIDGE HOSPITAL BEVERLY'},
#     {   'info': {   'CITY': 'LUDLOW',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'HAMPDEN',
#                     'ID': 12001056,
#                     'LATITUDE': 42.155775937,
#                     'LONGITUDE': -72.472077338,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'ENCOMPASS HEALTH HOSPITAL OF WESTERN MASS'},
#     {   'info': {   'CITY': 'COLUMBIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ADAIR',
#                     'ID': 12142728,
#                     'LATITUDE': 37.0966415730001,
#                     'LONGITUDE': -85.29454565,
#                     'STATE': 'KY',
#                     'STATUS': 'OPEN'},
#         'name': 'T J HEALTH COLUMBIA'},
#     {   'info': {   'CITY': 'LEON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'DECATUR',
#                     'ID': 13050144,
#                     'LATITUDE': 40.750934665,
#                     'LONGITUDE': -93.746940772,
#                     'STATE': 'IA',
#                     'STATUS': 'OPEN'},
#         'name': 'DECATUR COUNTY HOSPITAL'},
#     {   'info': {   'CITY': 'GARNETT',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ANDERSON',
#                     'ID': 4466032,
#                     'LATITUDE': 38.2798769950001,
#                     'LONGITUDE': -95.250338654,
#                     'STATE': 'KS',
#                     'STATUS': 'OPEN'},
#         'name': 'ANDERSON COUNTY HOSPITAL'},
#     {   'info': {   'CITY': 'LAKIN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'KEARNY',
#                     'ID': 7567860,
#                     'LATITUDE': 37.9465932690001,
#                     'LONGITUDE': -101.251929912,
#                     'STATE': 'KS',
#                     'STATUS': 'OPEN'},
#         'name': 'KEARNY COUNTY HOSPITAL'},
#     {   'info': {   'CITY': 'MINNEAPOLIS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'OTTAWA',
#                     'ID': 7767467,
#                     'LATITUDE': 39.1293319640001,
#                     'LONGITUDE': -97.7039442509999,
#                     'STATE': 'KS',
#                     'STATUS': 'OPEN'},
#         'name': 'OTTAWA COUNTY HEALTH CENTER'},
#     {   'info': {   'CITY': 'NEEDHAM',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'NORFOLK',
#                     'ID': 3502492,
#                     'LATITUDE': 42.2771000000001,
#                     'LONGITUDE': -71.2368999999999,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'BETH ISRAEL DEACONESS HOSPITAL - NEEDHAM'},
#     {   'info': {   'CITY': 'NEW BEDFORD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BRISTOL',
#                     'ID': 12402745,
#                     'LATITUDE': 41.740725232,
#                     'LONGITUDE': -70.945753607,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
# ...
#                     'LONGITUDE': -88.697254403,
#                     'STATE': 'MS',
#                     'STATUS': 'OPEN'},
#         'name': 'THE SPECIALTY HOSPITAL OF MERIDIAN'},
#     {   'info': {   'CITY': 'MONACILLO URBANO',
#                     'COUNTRY': 'PRI',
#                     'COUNTY': 'SAN JUAN',
#                     'ID': 5200922,
#                     'LATITUDE': 18.390593519,
#                     'LONGITUDE': -66.075929758,
#                     'STATE': 'PR',
#                     'STATUS': 'OPEN'},
#         'name': 'HOSP PSIQUIATRICO DR RAMON FERNANDEZ MARINA'},
#     {   'info': {   'CITY': 'SPOKANE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SPOKANE',
#                     'ID': 4399202,
#                     'LATITUDE': 47.6490353560001,
#                     'LONGITUDE': -117.409048054,
#                     'STATE': 'WA',
#                     'STATUS': 'OPEN'},
#         'name': "ST. LUKE'S REHABILITATION INSTITUTE"},
#     {   'info': {   'CITY': 'ABILENE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TAYLOR',
#                     'ID': 138479606,
#                     'LATITUDE': 32.3999670000001,
#                     'LONGITUDE': -99.739311,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'OCEANS BEHAVIORAL HOSPITAL OF ABILENE'},
#     {   'info': {   'CITY': 'CLEVELAND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LIBERTY',
#                     'ID': 10977328,
#                     'LATITUDE': 30.341782794,
#                     'LONGITUDE': -95.0853070969999,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'TEXAS EMERGENCY HOSPITAL'},
#     {   'info': {   'CITY': 'BEACHWOOD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CUYAHOGA',
#                     'ID': 189344122,
#                     'LATITUDE': 41.4649389640001,
#                     'LONGITUDE': -81.4989565879999,
#                     'STATE': 'OH',
#                     'STATUS': 'OPEN'},
#         'name': 'LAKE HEALTH BEACHWOOD MEDICAL CENTER'},
#     {   'info': {   'CITY': 'HENDERSON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CLARK',
#                     'ID': 191989052,
#                     'LATITUDE': 36.0031157230001,
#                     'LONGITUDE': -115.116944149,
#                     'STATE': 'NV',
#                     'STATUS': 'OPEN'},
#         'name': 'DIGNITY HEALTH REHABILITATION HOSPITAL'},
#     {   'info': {   'CITY': 'AUSTIN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TRAVIS',
#                     'ID': 191178732,
#                     'LATITUDE': 30.391346991,
#                     'LONGITUDE': -97.884934501,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'LAKE TRAVIS ER LLC'},
#     {   'info': {   'CITY': 'AYER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'WORCESTER',
#                     'ID': 18971434,
#                     'LATITUDE': 42.530255034,
#                     'LONGITUDE': -71.61498098,
#                     'STATE': 'MA',
#                     'STATUS': 'OPEN'},
#         'name': 'TARAVISTA BEHAVIORAL HEALTH CENTER'},
#     {   'info': {   'CITY': 'LAS VEGAS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CLARK',
#                     'ID': 190189109,
#                     'LATITUDE': 36.108767008,
#                     'LONGITUDE': -115.165855036,
#                     'STATE': 'NV',
#                     'STATUS': 'OPEN'},
#         'name': 'ELITE MEDICAL CENTER'},
#     {   'info': {   'CITY': 'PRAIRIEVILLE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ASCENSION',
#                     'ID': 190470769,
#                     'LATITUDE': 30.3178788930001,
#                     'LONGITUDE': -90.978556661,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'PRAIRIEVILLE FAMILY HOSPITAL'},
#     {   'info': {   'CITY': 'SPRINGDALE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'WASHINGTON',
#                     'ID': 190372762,
#                     'LATITUDE': 36.1624095,
#                     'LONGITUDE': -94.190464286,
#                     'STATE': 'AR',
#                     'STATUS': 'OPEN'},
#         'name': "ARKANSAS CHILDREN'S NORTHWEST INC."},
#     {   'info': {   'CITY': 'PEARLAND',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BRAZORIA',
#                     'ID': 188077584,
#                     'LATITUDE': 29.572905819,
#                     'LONGITUDE': -95.3898333289999,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'ENCOMPASS HEALTH REHABILITATION HOSPITAL OF PEARLAND'},
#     {   'info': {   'CITY': 'FORT WORTH',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TARRANT',
#                     'ID': 194876110,
#                     'LATITUDE': 32.727488926,
#                     'LONGITUDE': -97.347091835,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'BAYLOR SCOTT & WHITE SURGICAL HOSPITAL - FORT WORTH'},
#     {   'info': {   'CITY': 'FARGO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CASS',
#                     'ID': 194058104,
#                     'LATITUDE': 46.8101132850001,
#                     'LONGITUDE': -96.840822535,
#                     'STATE': 'ND',
#                     'STATUS': 'OPEN'},
#         'name': 'COBALT REHABILITATION HOSPITAL FARGO'},
#     {   'info': {   'CITY': 'LAKE CHARLES',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'CALCASIEU',
#                     'ID': 193570607,
#                     'LATITUDE': 30.182567238,
#                     'LONGITUDE': -93.189603865,
#                     'STATE': 'LA',
#                     'STATUS': 'OPEN'},
#         'name': 'OCEANS BEHAVIORAL HOSPITAL OF LAKE CHARLES'},
#     {   'info': {   'CITY': 'MIAMI',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MIAMI-DADE',
#                     'ID': 187833136,
#                     'LATITUDE': 25.79114988,
#                     'LONGITUDE': -80.2107186869999,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'UNIVERSITY OF MIAMI HOSPITAL AND CLINICS-BASCOM PALMER EYE '
#                 'INST'},
#     {   'info': {   'CITY': 'CHICAGO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'COOK',
#                     'ID': 196260611,
#                     'LATITUDE': 41.8940027140001,
#                     'LONGITUDE': -87.618437715,
#                     'STATE': 'IL',
#                     'STATUS': 'OPEN'},
#         'name': 'REHABILITATION INSTITUTE OF CHICAGO - DBA SHIRLEY RYAN '
#                 'ABILITYLAB'},
#     {   'info': {   'CITY': 'ARGYLE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'DENTON',
#                     'ID': 184076226,
#                     'LATITUDE': 33.132137141,
#                     'LONGITUDE': -97.204726057,
#                     'STATE': 'TX',
#                     'STATUS': 'OPEN'},
#         'name': 'WISE HEALTH SURGICAL HOSPITAL'},
#     {   'info': {   'CITY': 'LAKE MARY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SEMINOLE',
#                     'ID': 186432746,
#                     'LATITUDE': 28.769639,
#                     'LONGITUDE': -81.3483889999999,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'ARNOLD PALMER HOSPITAL FOR CHILDREN'},
#     {   'info': {   'CITY': 'WEDOWEE',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'RANDOLPH',
#                     'ID': 195436278,
#                     'LATITUDE': 33.295332,
#                     'LONGITUDE': -85.480689,
#                     'STATE': 'AL',
#                     'STATUS': 'OPEN'},
#         'name': 'TANNER MEDICAL CENTER/EAST ALABAMA'},
#     {   'info': {   'CITY': 'PENSACOLA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ESCAMBIA',
#                     'ID': 184632504,
#                     'LATITUDE': 30.4757070000001,
#                     'LONGITUDE': -87.211843,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'ASCENSION SACRED HEART HOSPITAL PENSACOLA'},
#     {   'info': {   'CITY': 'MADISON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MADISON',
#                     'ID': 192232340,
#                     'LATITUDE': 30.471301,
#                     'LONGITUDE': -83.418787,
#                     'STATE': 'FL',
#                     'STATUS': 'OPEN'},
#         'name': 'MADISON COUNTY MEMORIAL HOSPITAL'},
#     {   'info': {   'CITY': 'COPLEY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SUMMIT',
#                     'ID': 182444321,
#                     'LATITUDE': 41.136712,
#                     'LONGITUDE': -81.662342,
#                     'STATE': 'OH',
#                     'STATUS': 'OPEN'},
#         'name': 'CLEVELAND CLINIC REHABILITATION HOSPITAL, EDWIN SHAW'},
#     {   'info': {   'CITY': 'OXFORD',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LAFAYETTE',
#                     'ID': 195238655,
#                     'LATITUDE': 34.34799,
#                     'LONGITUDE': -89.529729,
#                     'STATE': 'MS',
#                     'STATUS': 'OPEN'},
#         'name': 'BAPTIST MEMORIAL HOSPITAL NORTH MS'},
#     {   'info': {   'CITY': 'LIBERTY TOWNSHIP',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BUTLER',
#                     'ID': 191245069,
#                     'LATITUDE': 39.3748180000001,
#                     'LONGITUDE': -84.362967,
#                     'STATE': 'OH',
#                     'STATUS': 'OPEN'},
#         'name': 'THE CHRIST HOSPITAL HEALTH NETWORK'},
#     {   'info': {   'CITY': 'ST. PETERS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ST CHARLES',
#                     'ID': 182663376,
#                     'LATITUDE': 38.793809982,
#                     'LONGITUDE': -90.579854812,
#                     'STATE': 'MO',
#                     'STATUS': 'OPEN'},
#         'name': 'THE REHABILITATION INSTITUTE OF ST. LOUIS'},
#     {   'info': {   'CITY': 'LAKE ST. LOUIS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ST. CHARLES',
#                     'ID': 183163367,
#                     'LATITUDE': 38.802534,
#                     'LONGITUDE': -90.775864,
#                     'STATE': 'MO',
#                     'STATUS': 'OPEN'},
#         'name': 'SSM HEALTH REHABILITATION HOSPITAL'},
#     {   'info': {   'CITY': "O'FALLON",
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ST CLAIR',
#                     'ID': 195962269,
#                     'LATITUDE': 38.5837720000001,
#                     'LONGITUDE': -89.932282,
#                     'STATE': 'IL',
#                     'STATUS': 'OPEN'},
#         'name': "HSHS ST ELIZABETH'S HOSPITAL"},
#     {   'info': {   'CITY': 'LAKE FOREST',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'LAKE',
#                     'ID': 196060045,
#                     'LATITUDE': 42.2557943240001,
#                     'LONGITUDE': -87.865414748,
#                     'STATE': 'IL',
#                     'STATUS': 'OPEN'},
#         'name': 'NORTHWESTERN LAKE FOREST HOSPITAL'},
#     {   'info': {   'CITY': 'COLUMBIA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BOONE',
#                     'ID': 191565202,
#                     'LATITUDE': 39.0070184730001,
#                     'LONGITUDE': -92.321547018,
#                     'STATE': 'MO',
#                     'STATUS': 'OPEN'},
#         'name': 'CENTERPOINTE HOSPITAL OF COLUMBIA'},
#     {   'info': {   'CITY': 'BLUFFTON',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'BEAUFORT',
#                     'ID': 187429910,
#                     'LATITUDE': 32.285740661,
#                     'LONGITUDE': -80.940485768,
#                     'STATE': 'SC',
#                     'STATUS': 'OPEN'},
#         'name': 'ENCOMPASS HEALTH REHABILITATION HOSPITAL OF BLUFFTON'},
#     {   'info': {   'CITY': 'LITTLE RIVER',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'HORRY',
#                     'ID': 192329566,
#                     'LATITUDE': 33.8664190000001,
#                     'LONGITUDE': -78.660205,
#                     'STATE': 'SC',
#                     'STATUS': 'OPEN'},
#         'name': 'TIDELANDS HEALTH REHABILITATION HOSPITAL AT LITTLE RIVER AN'},
#     {   'info': {   'CITY': 'OWENSBORO',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'DAVIESS',
#                     'ID': 187942303,
#                     'LATITUDE': 37.779484499,
#                     'LONGITUDE': -87.0642916529999,
#                     'STATE': 'KY',
#                     'STATUS': 'OPEN'},
#         'name': 'OWENSBORO HEALTH REGIONAL HOSPITAL'},
#     {   'info': {   'CITY': 'NEW HYDE PARK',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'QUEENS',
#                     'ID': 193711040,
#                     'LATITUDE': 40.7530050890001,
#                     'LONGITUDE': -73.708456543,
#                     'STATE': 'NY',
#                     'STATUS': 'OPEN'},
#         'name': 'COHEN CHILDREN’S MEDICAL CENTER'},
#     {   'info': {   'CITY': 'EUPORA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'WEBSTER',
#                     'ID': 193339744,
#                     'LATITUDE': 33.5339256080001,
#                     'LONGITUDE': -89.2663569919999,
#                     'STATE': 'MS',
#                     'STATUS': 'OPEN'},
#         'name': 'NORTH MS MEDICAL CENTER - EUPORA'},
#     {   'info': {   'CITY': 'IUKA',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'TISHOMINGO',
#                     'ID': 185838852,
#                     'LATITUDE': 34.8018562350001,
#                     'LONGITUDE': -88.2083545099999,
#                     'STATE': 'MS',
#                     'STATUS': 'OPEN'},
#         'name': 'NORTH MS MEDICAL CENTER - IUKA'},
#     {   'info': {   'CITY': 'SILVER SPRING',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MONTGOMERY',
#                     'ID': 183520904,
#                     'LATITUDE': 39.04985358,
#                     'LONGITUDE': -76.9578213839999,
#                     'STATE': 'MD',
#                     'STATUS': 'OPEN'},
#         'name': 'ADVENTIST HEALTHCARE WHITE OAK MEDICAL CENTER'},
#     {   'info': {   'CITY': 'DOUGLAS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'COCHISE',
#                     'ID': 192185607,
#                     'LATITUDE': 31.339594366,
#                     'LONGITUDE': -109.560682188,
#                     'STATE': 'AZ',
#                     'STATUS': 'OPEN'},
#         'name': 'COPPER QUEEN DOUGLAS EMERGENCY DEPARTMENT'},
#     {   'info': {   'CITY': 'MIDDLETOWN',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'MIDDLESEX',
#                     'ID': 196706457,
#                     'LATITUDE': 41.55204,
#                     'LONGITUDE': -72.625890402,
#                     'STATE': 'CT',
#                     'STATUS': 'OPEN'},
#         'name': 'WHITING FORENSIC HOSPITAL'},
#     {   'info': {   'CITY': 'ANNAPOLIS',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'ANNE ARUNDEL',
#                     'ID': 191021401,
#                     'LATITUDE': 38.9779384140001,
#                     'LONGITUDE': -76.5582285369999,
#                     'STATE': 'MD',
#                     'STATUS': 'OPEN'},
#         'name': 'J KENT MCNEW FAMILY MEDICAL CENTER'},
#     {   'info': {   'CITY': 'SALT LAKE CITY',
#                     'COUNTRY': 'USA',
#                     'COUNTY': 'SALT LAKE',
#                     'ID': 196784108,
#                     'LATITUDE': 40.756338688,
#                     'LONGITUDE': -111.833183755,
#                     'STATE': 'UT',
#                     'STATUS': 'OPEN'},
#         'name': 'UNIVERSITY ORTHOPAEDIC CENTER'}]

# %%
# Export the DataFrame to a CSV file
filtered_hospitals_df.to_csv('cleaned_hospitals_data.csv', index=False)
