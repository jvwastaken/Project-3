# %%
import sqlite3

# %%
conn = sqlite3.connect('data.sqlite')
conn.row_factory = sqlite3.Row
db = conn.cursor()

rows = db.execute("SELECT * FROM hospitals").fetchall()

conn.commit()
conn.close()

# %%
[dict(row) for row in rows]
# Out:
# [{'Id': 53391362,
#   'Name': 'Los Robles Hospital & Medical Center - East Campus',
#   'Address': '150 Via Merida',
#   'City': 'Westlake Vilage',
#   'County': 'Ventura',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.1549388720001,
#   'Longitude': -118.815736391,
#   'Beds': 62,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 11190023,
#   'Name': 'East Los Angeles Doctors Hospital',
#   'Address': '4060 Whittier Boulevard',
#   'City': 'Los Angeles',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.023647302,
#   'Longitude': -118.184164805,
#   'Beds': 127,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 17090028,
#   'Name': 'Southern California Hospital At Hollywood',
#   'Address': '6245 De Longpre Avenue',
#   'City': 'Hollywood',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.0963913570001,
#   'Longitude': -118.325234871,
#   'Beds': 100,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 23691706,
#   'Name': 'Kindred Hospital Baldwin Park',
#   'Address': '14148 Francisquito Avenue',
#   'City': 'Baldwin Park',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.063038932,
#   'Longitude': -117.967437788,
#   'Beds': 95,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 25190712,
#   'Name': 'Lakewood Regional Medical Center',
#   'Address': '3700 East South Street',
#   'City': 'Lakewood',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8597066200001,
#   'Longitude': -118.148402965,
#   'Beds': 172,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 30791016,
#   'Name': 'Monrovia Memorial Hospital',
#   'Address': '323 South Heliotrope Avenue',
#   'City': 'Monrovia',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.1487586590001,
#   'Longitude': -117.992667657,
#   'Beds': 49,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 30891754,
#   'Name': 'Monterey Park Hospital',
#   'Address': '900 South Atlantic Boulevard',
#   'City': 'Monterey Park',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.0494660590001,
#   'Longitude': -118.138262231,
#   'Beds': 101,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 47090505,
#   'Name': 'Star View Adolescent - P H F',
#   'Address': '4025 West 226 Street',
#   'City': 'Torrance',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.823914464,
#   'Longitude': -118.356096947,
#   'Beds': 16,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 9092879,
#   'Name': 'Corona Regional Medical Center-Magnolia',
#   'Address': '730 Magnolia Avenue',
#   'City': 'Corona',
#   'County': 'Riverside',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8580833070001,
#   'Longitude': -117.553858035,
#   'Beds': 78,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 30696101,
#   'Name': 'Modoc Medical Center',
#   'Address': '228 Mc Dowell Street',
#   'City': 'Alturas',
#   'County': 'Modoc',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 41.4800562550001,
#   'Longitude': -120.545743987,
#   'Beds': 87,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 38593901,
#   'Name': 'Salinas Valley Memorial Hospital',
#   'Address': '450 East Romie Lane',
#   'City': 'Salinas',
#   'County': 'Monterey',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 36.659030456,
#   'Longitude': -121.645983804,
#   'Beds': 269,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 15992866,
#   'Name': "Healthbridge Children'S Hospital-Orange",
#   'Address': '393 S. Tustin Street',
#   'City': 'Orange',
#   'County': 'Orange',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.7827271730001,
#   'Longitude': -117.833891865,
#   'Beds': 27,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 16192680,
#   'Name': 'Healthsouth Tustin Rehabilitation Hospital',
#   'Address': '14851 Yorba Street',
#   'City': 'Tustin',
#   'County': 'Orange',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.7474607400001,
#   'Longitude': -117.831055631,
#   'Beds': 48,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 23792621,
#   'Name': 'Kindred Hospital Brea',
#   'Address': '875 North Brea Boulevard',
#   'City': 'Brea',
#   'County': 'Orange',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.934495886,
#   'Longitude': -117.893948792,
#   'Beds': 86,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 24392683,
#   'Name': 'Kindred Hospital Westminster',
#   'Address': '200 Hospital Circle',
#   'City': 'Westminster',
#   'County': 'Orange',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.7635332090001,
#   'Longitude': -117.995255963,
#   'Beds': 109,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 22093277,
#   'Name': 'Kaweah Delta Mental Health Hospital D/P Aph',
#   'Address': '1100 So. Akers Street',
#   'City': 'Visalia',
#   'County': 'Tulare',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 36.320843946,
#   'Longitude': -119.348234528,
#   'Beds': 63,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5870563,
#   'Name': 'Dauterive Hospital',
#   'Address': '600 N Lewis Ave.',
#   'City': 'New Iberia',
#   'County': 'Iberia',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 30.006906977,
#   'Longitude': -91.794523853,
#   'Beds': 103,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 13177954,
#   'Name': 'Crockett Medical Center',
#   'Address': '1100 East Loop 304',
#   'City': 'Crockett',
#   'County': 'Houston',
#   'State': 'Texas',
#   'Status': 'Open',
#   'Latitude': 31.32360364,
#   'Longitude': -95.4388993059999,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 4671360,
#   'Name': 'Central Louisiana State Hospital',
#   'Address': '242 W Shamrock Ave',
#   'City': 'Pineville',
#   'County': 'Rapides',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 31.3273789420001,
#   'Longitude': -92.4401351129999,
#   'Beds': 128,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 15671222,
#   'Name': 'Reeves Memorial Medical Center',
#   'Address': '409 1St St',
#   'City': 'Bernice',
#   'County': 'Union',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 32.8239916700001,
#   'Longitude': -92.656648681,
#   'Beds': 11,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 16971241,
#   'Name': 'Serenity Springs Specialty Hospital',
#   'Address': '309 N Main St',
#   'City': 'Farmerville',
#   'County': 'Union',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 32.776127934,
#   'Longitude': -92.4056258479999,
#   'Beds': 18,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 15371373,
#   'Name': 'Riverbridge Specialty Hospital',
#   'Address': '209 Front St.',
#   'City': 'Vidalia',
#   'County': 'Concordia',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 31.5611748630001,
#   'Longitude': -91.4260669829999,
#   'Beds': 40,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5371418,
#   'Name': 'Citizens Medical Center',
#   'Address': '7939 Highway 165',
#   'City': 'Columbia',
#   'County': 'Caldwell',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 32.0600399510001,
#   'Longitude': -92.099137669,
#   'Beds': 40,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 70990806,
#   'Name': 'College Medical Center',
#   'Address': '2776 Pacific Avenue',
#   'City': 'Long Beach',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8070928700001,
#   'Longitude': -118.193389929,
#   'Beds': 121,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 71794577,
#   'Name': 'Kaiser Foundation Hospital - San Leandro',
#   'Address': '2500 Merced Street',
#   'City': 'San Leandro',
#   'County': 'Alameda',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.706406198,
#   'Longitude': -122.164654518,
#   'Beds': 216,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 72590723,
#   'Name': 'Kindred Hospital Paramount',
#   'Address': '16453 South Colorado Avenue',
#   'City': 'Paramount',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8846318610001,
#   'Longitude': -118.162267066,
#   'Beds': 177,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 73790650,
#   'Name': 'Department Of State Hospital-Metropolitan',
#   'Address': '11401 Bloomfield Avenue',
#   'City': 'Norwalk',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.928031349,
#   'Longitude': -118.067989672,
#   'Beds': 1265,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 196162274,
#   'Name': 'Pinckneyville Community Hospital',
#   'Address': '5383 State Route 154',
#   'City': 'Pinckneyville',
#   'County': 'Perry',
#   'State': 'Illinois',
#   'Status': 'Open',
#   'Latitude': 38.084846,
#   'Longitude': -89.3491079999999,
#   'Beds': 17,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 85531419,
#   'Name': "St Joseph'S Hospital - Savannah",
#   'Address': '11705 Mercy Boulevard',
#   'City': 'Savannah',
#   'County': 'Chatham',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 31.985430321,
#   'Longitude': -81.154556369,
#   'Beds': 294,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 86630165,
#   'Name': 'Kindred Hospital Rome',
#   'Address': '320 Turner Mccall Boulevard',
#   'City': 'Rome',
#   'County': 'Floyd',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 34.259713445,
#   'Longitude': -85.1802396319999,
#   'Beds': 45,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 87130286,
#   'Name': 'Upson Regional Medical Center',
#   'Address': '801 W Gordon Street',
#   'City': 'Thomaston',
#   'County': 'Upson',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 32.886297701,
#   'Longitude': -84.3365069879999,
#   'Beds': 115,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 87531719,
#   'Name': 'Phoebe Sumter Medical Center',
#   'Address': '126 Highway 280 W',
#   'City': 'Americus',
#   'County': 'Sumter',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 32.0669623380001,
#   'Longitude': -84.2560501999999,
#   'Beds': 76,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 87931830,
#   'Name': 'Roosevelt Warm Springs Ltac Hospital',
#   'Address': '6135 Roosevelt Highway',
#   'City': 'Warm Springs',
#   'County': 'Meriwether',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 32.887980741,
#   'Longitude': -84.6923449,
#   'Beds': 32,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 90030265,
#   'Name': 'Southeastern Regional Medical Center',
#   'Address': '600 Celebrate Life Pkwy',
#   'City': 'Newnan',
#   'County': 'Coweta',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 33.3848346460001,
#   'Longitude': -84.757746692,
#   'Beds': 50,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 2054311,
#   'Name': 'Brown Cty Community Treatment Center',
#   'Address': '3150 Gershwin Drive',
#   'City': 'Green Bay',
#   'County': 'Brown',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 44.522712261,
#   'Longitude': -87.924827084,
#   'Beds': 16,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 151253226,
#   'Name': 'Wheaton Franciscan Wi Heart Spine And Ortho',
#   'Address': '10000 West Bluemound Road',
#   'City': 'Wauwatosa',
#   'County': 'Milwaukee',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.0358121520001,
#   'Longitude': -88.037265823,
#   'Beds': 40,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 159171301,
#   'Name': 'Compass Behavioral Center Of Alexandria',
#   'Address': '6410 Masonic Drive',
#   'City': 'Alexandria',
#   'County': 'Rapides',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 31.252191558,
#   'Longitude': -92.481987814,
#   'Beds': 18,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 163570394,
#   'Name': 'Ocshner St. Anne General Hospital',
#   'Address': '4608 Highway 1',
#   'City': 'Raceland',
#   'County': 'Lafourche',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 29.7026714240001,
#   'Longitude': -90.565253898,
#   'Beds': 38,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 160970056,
#   'Name': 'United Medical Healthwest-New Orleans',
#   'Address': '3201 Wall Boulevard',
#   'City': 'Gretna',
#   'County': 'Jefferson',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 29.865979474,
#   'Longitude': -90.03069185,
#   'Beds': 14,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 152354971,
#   'Name': 'Ripon Medical Center',
#   'Address': '845 Parkside St',
#   'City': 'Ripon',
#   'County': 'Fond Du Lac',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.8343760920001,
#   'Longitude': -88.817751529,
#   'Beds': 18,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 5854452,
#   'Name': 'Ascension Good Samaritan Hlth Ctr',
#   'Address': '601 S Center Ave',
#   'City': 'Merrill',
#   'County': 'Lincoln',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 45.1756325370001,
#   'Longitude': -89.681831276,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 58796001,
#   'Name': 'Restpadd Psychiatric Health Facility',
#   'Address': '2750 Eureka Way',
#   'City': 'Redding',
#   'County': 'Shasta',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 40.586595392,
#   'Longitude': -122.411974107,
#   'Beds': 16,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 59093436,
#   'Name': 'The Champion Center',
#   'Address': '303 South C Street',
#   'City': 'Lompoc',
#   'County': 'Santa Barbara',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.6353716090001,
#   'Longitude': -120.452188325,
#   'Beds': 34,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 21891761,
#   'Name': 'Kaiser Fnd Hosp Ontario Medical Center Campus',
#   'Address': '2295 S. Vineyard Avenue',
#   'City': 'Ontario',
#   'County': 'San Bernardino',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.0320795600001,
#   'Longitude': -117.60859933,
#   'Beds': 176,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 25692354,
#   'Name': 'Loma Linda Univ. Med. Center East Campus Hospital',
#   'Address': '25333 Barton Road',
#   'City': 'Loma Linda',
#   'County': 'San Bernardino',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.047305635,
#   'Longitude': -117.251636776,
#   'Beds': 134,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 44792404,
#   'Name': 'St. Bernardine Medical Center',
#   'Address': '2101 North Waterman Avenue',
#   'City': 'San Bernardino',
#   'County': 'San Bernardino',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.1346723570001,
#   'Longitude': -117.277019975,
#   'Beds': 342,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 20092120,
#   'Name': 'Kaiser Fnd Hosp - San Diego',
#   'Address': '4647 Zion Avenue',
#   'City': 'San Diego',
#   'County': 'San Diego',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 32.7915625750001,
#   'Longitude': -117.095159549,
#   'Beds': 414,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 40992037,
#   'Name': 'Scripps Green Hospital',
#   'Address': '10666 North Torrey Pines Road',
#   'City': 'La Jolla',
#   'County': 'San Diego',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 32.896858901,
#   'Longitude': -117.24287107,
#   'Beds': 173,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 41092024,
#   'Name': 'Scripps Memorial Hospital - Encinitas',
#   'Address': '354 Santa Fe Drive',
#   'City': 'Encinitas',
#   'County': 'San Diego',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.0373447760001,
#   'Longitude': -117.284183383,
#   'Beds': 194,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 42292123,
#   'Name': 'Sharp Mary Birch Hospital For Women And Newborns',
#   'Address': '3003 Health Center Drive',
#   'City': 'San Diego',
#   'County': 'San Diego',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 32.7982957780001,
#   'Longitude': -117.154977819,
#   'Beds': 206,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 51092103,
#   'Name': 'Uc San Diego Health Hillcrest - Hillcrest Medical Center',
#   'Address': '200 West Arbor Drive',
#   'City': 'San Diego',
#   'County': 'San Diego',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 32.754770233,
#   'Longitude': -117.165731384,
#   'Beds': 390,
#   'Trauma': 'Level I',
#   'Helipad': 'Y'},
#  {'Id': 4894118,
#   'Name': 'California Pacific Med Ctr-California West',
#   'Address': '3700 California Street',
#   'City': 'San Francisco',
#   'County': 'San Francisco',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.786509197,
#   'Longitude': -122.456030633,
#   'Beds': 299,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5094115,
#   'Name': 'California Pacific Med Ctr-Pacific Campus',
#   'Address': '2333 Buchanan Street',
#   'City': 'San Francisco',
#   'County': 'San Francisco',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.7907045380001,
#   'Longitude': -122.431294533,
#   'Beds': 309,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 46594117,
#   'Name': "St. Mary'S Medical Center, San Francisco",
#   'Address': '450 Stanyan Street',
#   'City': 'San Francisco',
#   'County': 'San Francisco',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.77408876,
#   'Longitude': -122.453751642,
#   'Beds': 403,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 20595403,
#   'Name': 'Kaiser Fnd Hosp - Santa Rosa',
#   'Address': '401 Bicentennial Way',
#   'City': 'Santa Rosa',
#   'County': 'Sonoma',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 38.471793006,
#   'Longitude': -122.72706436,
#   'Beds': 173,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 19594590,
#   'Name': 'Kaiser Fnd Hosp - Rehabilitation Center Vallejo',
#   'Address': '975 Sereno Drive',
#   'City': 'Vallejo',
#   'County': 'Solano',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 38.12690208,
#   'Longitude': -122.248377304,
#   'Beds': 248,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 53195695,
#   'Name': 'Woodland Memorial Hospital',
#   'Address': '1325 Cottonwood Street',
#   'City': 'Woodland',
#   'County': 'Yolo',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 38.663925024,
#   'Longitude': -121.792145249,
#   'Beds': 108,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 1294609,
#   'Name': 'Alta Bates Summit Med Ctr-Summit Campus-Summit',
#   'Address': '3100 Summit Street',
#   'City': 'Oakland',
#   'County': 'Alameda',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.8201396110001,
#   'Longitude': -122.26400415,
#   'Beds': 75,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 39794578,
#   'Name': 'San Leandro Hospital',
#   'Address': '13855 East 14Th Street',
#   'City': 'San Leandro',
#   'County': 'Alameda',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.712288347,
#   'Longitude': -122.143493689,
#   'Beds': 93,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 46694545,
#   'Name': 'St. Rose Hospital',
#   'Address': '27200 Calaroga Avenue',
#   'City': 'Hayward',
#   'County': 'Alameda',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.6334419930001,
#   'Longitude': -122.087912534,
#   'Beds': 217,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 45995204,
#   'Name': "St. Joseph'S Behavioral Health Center",
#   'Address': '2510 North California Street',
#   'City': 'Stockton',
#   'County': 'San Joaquin',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.9765963,
#   'Longitude': -121.291070926,
#   'Beds': 35,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 46095204,
#   'Name': "St. Joseph'S Medical Center Of Stockton",
#   'Address': '1800 North California Street',
#   'City': 'Stockton',
#   'County': 'San Joaquin',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.970467188,
#   'Longitude': -121.288182762,
#   'Beds': 364,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 13291741,
#   'Name': 'Foothill Presbyterian Hospital-Johnston Memorial',
#   'Address': '250 South Grand Avenue',
#   'City': 'Glendora',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.132654576,
#   'Longitude': -117.871259716,
#   'Beds': 105,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 14791204,
#   'Name': 'Glendale Memorial Hospital And Health Center',
#   'Address': '1420 South Central Avenue',
#   'City': 'Glendale',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.128165628,
#   'Longitude': -118.256643169,
#   'Beds': 334,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 19090027,
#   'Name': 'Kaiser Foundation Los Angeles Medical Center',
#   'Address': '4867 Sunset Boulevard',
#   'City': 'Los Angeles',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.0985736490001,
#   'Longitude': -118.294175331,
#   'Beds': 460,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 19391402,
#   'Name': 'Kaiser Permanente Panorama City',
#   'Address': '13652 Cantara Street',
#   'City': 'Panorama City',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.2185641940001,
#   'Longitude': -118.430219294,
#   'Beds': 218,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 36691356,
#   'Name': 'Providence Tarzana Medical Center',
#   'Address': '18321 Clark Street',
#   'City': 'Tarzana',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.170393216,
#   'Longitude': -118.531904059,
#   'Beds': 249,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 42990020,
#   'Name': 'Shriners Hospital For Children - L.A.',
#   'Address': '3160 Geneva Street',
#   'City': 'Los Angeles',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.067204777,
#   'Longitude': -118.286392079,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 50190716,
#   'Name': 'Gardens Regional Hospital And Medical Center',
#   'Address': '21530 South Pioneer Boulevard',
#   'City': 'Hawaiian Gardens',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.833640007,
#   'Longitude': -118.079677951,
#   'Beds': 107,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 45295422,
#   'Name': 'Adventist Health Clearlake',
#   'Address': '15630 18Th Ave - Hwy 53',
#   'City': 'Clearlake',
#   'County': 'Lake',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 38.935618855,
#   'Longitude': -122.620144532,
#   'Beds': 32,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 6193638,
#   'Name': "Valley Children'S Hospital",
#   'Address': "9300 Valley Children'S Place",
#   'City': 'Madera',
#   'County': 'Madera',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 36.8840478340001,
#   'Longitude': -119.800242412,
#   'Beds': 356,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 11792270,
#   'Name': 'Eisenhower Medical Center',
#   'Address': '39-000 Bob Hope Drive',
#   'City': 'Rancho Mirage',
#   'County': 'Riverside',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.7633520680001,
#   'Longitude': -116.406241091,
#   'Beds': 489,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 15295124,
#   'Name': 'Good Samaritan Hospital-San Jose',
#   'Address': '2425 Samaritan Drive',
#   'City': 'San Jose',
#   'County': 'Santa Clara',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.252078736,
#   'Longitude': -121.946576875,
#   'Beds': 404,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 20495051,
#   'Name': 'Kaiser Fnd Hosp - Santa Clara',
#   'Address': '700 Lawrence Expressway',
#   'City': 'Santa Clara',
#   'County': 'Santa Clara',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.3354013750001,
#   'Longitude': -121.998873047,
#   'Beds': 327,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 27094304,
#   'Name': "Lucile Salter Packard Children'S Hosp. At Stanford",
#   'Address': '725 Welch Road',
#   'City': 'Palo Alto',
#   'County': 'Santa Clara',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.436004575,
#   'Longitude': -122.175390036,
#   'Beds': 302,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 19494063,
#   'Name': 'Kaiser Fnd Hosp - Redwood City',
#   'Address': '1100 Veterans Boulevard',
#   'City': 'Redwood City',
#   'County': 'San Mateo',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.488847836,
#   'Longitude': -122.223390131,
#   'Beds': 149,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 18094520,
#   'Name': 'John Muir Medical Center-Concord Campus',
#   'Address': '2540 East Street',
#   'City': 'Concord',
#   'County': 'Contra Costa',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.9830895790001,
#   'Longitude': -122.033496796,
#   'Beds': 245,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 47794509,
#   'Name': 'Sutter Delta Medical Center',
#   'Address': '3901 Lone Tree Way',
#   'City': 'Antioch',
#   'County': 'Contra Costa',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 37.9822344500001,
#   'Longitude': -121.802978505,
#   'Beds': 145,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 19995825,
#   'Name': 'Kaiser Fnd Hosp - Sacramento',
#   'Address': '2025 Morse Avenue',
#   'City': 'Sacramento',
#   'County': 'Sacramento',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 38.601797751,
#   'Longitude': -121.393144026,
#   'Beds': 287,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 43195945,
#   'Name': 'Sierra Nevada Memorial Hospital',
#   'Address': '155 Glasson Way',
#   'City': 'Grass Valley',
#   'County': 'Nevada',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 39.228016294,
#   'Longitude': -121.047499779,
#   'Beds': 104,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 24690623,
#   'Name': 'La Palma Intercommunity Hospital',
#   'Address': '7901 Walker Street',
#   'City': 'La Palma',
#   'County': 'Orange',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8475141810001,
#   'Longitude': -118.038302332,
#   'Beds': 141,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 13795991,
#   'Name': 'Fremont Medical Center',
#   'Address': '970 Plumas Street',
#   'City': 'Yuba City',
#   'County': 'Sutter',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 39.143106319,
#   'Longitude': -121.618012022,
#   'Beds': 46,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 10230143,
#   'Name': 'Piedmont Mountainside Hospital',
#   'Address': '1266 East Church Street',
#   'City': 'Jasper',
#   'County': 'Pickens',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 34.4582486800001,
#   'Longitude': -84.412912891,
#   'Beds': 52,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 15530606,
#   'Name': 'St Marys Health Care System',
#   'Address': '1230 Baxter Street',
#   'City': 'Athens',
#   'County': 'Clarke',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 33.9472213170001,
#   'Longitude': -83.4052524589999,
#   'Beds': 196,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 14130080,
#   'Name': 'Ridgeview Institute',
#   'Address': '3995 South Cobb Drive Se',
#   'City': 'Smyrna',
#   'County': 'Cobb',
#   'State': 'Georgia',
#   'Status': 'Open',
#   'Latitude': 33.8564432910001,
#   'Longitude': -84.51105483,
#   'Beds': 216,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 502891,
#   'Name': 'Westerly Hospital',
#   'Address': '25 Wells St',
#   'City': 'Westerly',
#   'County': 'Washington',
#   'State': 'Rhode Island',
#   'Status': 'Open',
#   'Latitude': 41.3621890750001,
#   'Longitude': -71.825303241,
#   'Beds': 125,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 1553715,
#   'Name': 'St Marys Hospital Madison',
#   'Address': '700 South Park St',
#   'City': 'Madison',
#   'County': 'Dane',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.0593384640001,
#   'Longitude': -89.401429215,
#   'Beds': 440,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 8253213,
#   'Name': 'Aurora Psychiatric Hsptl',
#   'Address': '1220 Dewey Ave',
#   'City': 'Wauwatosa',
#   'County': 'Milwaukee',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.046765098,
#   'Longitude': -88.007716433,
#   'Beds': 105,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 9753097,
#   'Name': 'Columbia Center',
#   'Address': '13125 N Port Washington Rd',
#   'City': 'Mequon',
#   'County': 'Ozaukee',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.256677929,
#   'Longitude': -87.926157962,
#   'Beds': 17,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 4354923,
#   'Name': 'Thedacare Medical Center Berlin',
#   'Address': '225 Memorial Drive',
#   'City': 'Berlin',
#   'County': 'Green Lake',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.9784771540001,
#   'Longitude': -88.94122636,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 63072758,
#   'Name': 'Mercy Hospital Rogers',
#   'Address': '2710 Rife Medical Lane',
#   'City': 'Rogers',
#   'County': 'Benton',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.3089928530001,
#   'Longitude': -94.18297802,
#   'Beds': 208,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 10454024,
#   'Name': 'St Croix Reg Med Ctr',
#   'Address': '235 State Street',
#   'City': 'Saint Croix Falls',
#   'County': 'Polk',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 45.4090324310001,
#   'Longitude': -92.642578117,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 11854017,
#   'Name': 'Westfields Hospital',
#   'Address': '535 Hospital Rd',
#   'City': 'New Richmond',
#   'County': 'St. Croix',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 45.1177607480001,
#   'Longitude': -92.555500378,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 12453081,
#   'Name': 'St Nicholas Hospital',
#   'Address': '3100 Superior Ave',
#   'City': 'Sheboygan',
#   'County': 'Sheboygan',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.7623479010001,
#   'Longitude': -87.747537955,
#   'Beds': 185,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 13154665,
#   'Name': 'Vernon Mem Hsptl',
#   'Address': '507 South Main St',
#   'City': 'Viroqua',
#   'County': 'Vernon',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 43.551673973,
#   'Longitude': -90.888391278,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'N'},
#  {'Id': 72390241,
#   'Name': 'Pih Hospital - Downey',
#   'Address': '11500 Brookshire Avenue',
#   'City': 'Downey',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.9343517980001,
#   'Longitude': -118.13090396,
#   'Beds': 199,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 72790503,
#   'Name': 'Providence Little Company Of Mary Transitional Care Center',
#   'Address': '4320 Maricopa Street',
#   'City': 'Torrance',
#   'County': 'Los Angeles',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 33.8393481160001,
#   'Longitude': -118.359721519,
#   'Beds': 115,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 58592354,
#   'Name': "Loma Linda University Children'S Hospital",
#   'Address': '11234 Anderson Street',
#   'City': 'Loma Linda',
#   'County': 'San Bernardino',
#   'State': 'California',
#   'Status': 'Open',
#   'Latitude': 34.050130832,
#   'Longitude': -117.264094455,
#   'Beds': 343,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 15254904,
#   'Name': 'Ascension Ne Wisconsin Mercy Campus',
#   'Address': '500 S Oakwood Rd',
#   'City': 'Oshkosh',
#   'County': 'Winnebago',
#   'State': 'Wisconsin',
#   'Status': 'Open',
#   'Latitude': 44.0124207170001,
#   'Longitude': -88.601045493,
#   'Beds': 157,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 75420007,
#   'Name': 'Medstar-Georgetown University Medical Center',
#   'Address': '3800 Reservoir Road, Nw',
#   'City': 'Washington',
#   'County': 'District of Columbia',
#   'State': 'District of Columbia',
#   'Status': 'Open',
#   'Latitude': 38.9119585080001,
#   'Longitude': -77.0752545729999,
#   'Beds': 609,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 31233525,
#   'Name': 'Advent Health Dade City',
#   'Address': '13100 Fort King Rd',
#   'City': 'Dade City',
#   'County': 'Pasco',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.3479628600001,
#   'Longitude': -82.2007200799999,
#   'Beds': 120,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 7233484,
#   'Name': 'Delray Medical Center',
#   'Address': '5352 Linton Blvd',
#   'City': 'Delray Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.4371928410001,
#   'Longitude': -80.127787747,
#   'Beds': 536,
#   'Trauma': 'Level I',
#   'Helipad': 'Y'},
#  {'Id': 36034758,
#   'Name': 'Poinciana Medical Center',
#   'Address': '325 Cypress Pkwy',
#   'City': 'Kissimmee',
#   'County': 'Osceola',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.144780763,
#   'Longitude': -81.476687855,
#   'Beds': 76,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 9802703,
#   'Name': 'Arbour Fuller Hospital',
#   'Address': '200 May Street',
#   'City': 'Attleboro',
#   'County': 'Bristol',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 41.9240838480001,
#   'Longitude': -71.3611225619999,
#   'Beds': 103,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 9702146,
#   'Name': 'Arbour Human Resource Institute',
#   'Address': '227 Babcock Street',
#   'City': 'Brookline',
#   'County': 'Norfolk',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.3507795100001,
#   'Longitude': -71.121242281,
#   'Beds': 66,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 36232068,
#   'Name': "Assencion St. Vincent'S Medical Center Clay County",
#   'Address': "1670 St. Vincent'S Way",
#   'City': 'Middleburg',
#   'County': 'Clay',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 30.108762428,
#   'Longitude': -81.832688692,
#   'Beds': 106,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 36334471,
#   'Name': 'Encompass Health Rehabilitation Hospital Of Ocala',
#   'Address': '2275 Sw 22Nd Lane',
#   'City': 'Ocala',
#   'County': 'Marion',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 29.165875541,
#   'Longitude': -82.1623349449999,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 3906250,
#   'Name': 'Natchaug Hospital, Inc.',
#   'Address': '189 Storrs Rd',
#   'City': 'Mansfield Center',
#   'County': 'Tolland',
#   'State': 'Connecticut',
#   'Status': 'Open',
#   'Latitude': 41.7411039190001,
#   'Longitude': -72.198011482,
#   'Beds': 57,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 36634997,
#   'Name': 'Encompass Health Rehabilitation Hospital At Martin Health',
#   'Address': '5850 Se Community Dr',
#   'City': 'Stuart',
#   'County': 'Martin',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 27.133437293,
#   'Longitude': -80.222455815,
#   'Beds': 54,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 10502114,
#   'Name': "Shriners' Hospital For Children",
#   'Address': '51 Blossom St',
#   'City': 'Boston',
#   'County': 'Suffolk',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.3630925480001,
#   'Longitude': -71.066301879,
#   'Beds': 30,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 10602129,
#   'Name': 'Spaulding Rehabilitation Hospital',
#   'Address': '300 1St Ave',
#   'City': 'Boston',
#   'County': 'Suffolk',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.3785090760001,
#   'Longitude': -71.049055546,
#   'Beds': 132,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 11402720,
#   'Name': 'Dr John C Corrigan Mental Health Center',
#   'Address': '49 Hillside Street',
#   'City': 'Fall River',
#   'County': 'Bristol',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 41.707486913,
#   'Longitude': -71.145714465,
#   'Beds': 16,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12101904,
#   'Name': 'Bay Ridge Hospital Beverly',
#   'Address': '60 Granite Street',
#   'City': 'Lynn',
#   'County': 'Essex',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.471620106,
#   'Longitude': -70.956760931,
#   'Beds': 62,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12001056,
#   'Name': 'Encompass Health Hospital Of Western Mass',
#   'Address': '222 State Street',
#   'City': 'Ludlow',
#   'County': 'Hampden',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.155775937,
#   'Longitude': -72.472077338,
#   'Beds': 53,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12142728,
#   'Name': 'T J Health Columbia',
#   'Address': '901 Westlake Drive',
#   'City': 'Columbia',
#   'County': 'Adair',
#   'State': 'Kentucky',
#   'Status': 'Open',
#   'Latitude': 37.0966415730001,
#   'Longitude': -85.29454565,
#   'Beds': 74,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 13050144,
#   'Name': 'Decatur County Hospital',
#   'Address': '1405 Northwest Church Street',
#   'City': 'Leon',
#   'County': 'Decatur',
#   'State': 'Iowa',
#   'Status': 'Open',
#   'Latitude': 40.750934665,
#   'Longitude': -93.746940772,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 4466032,
#   'Name': 'Anderson County Hospital',
#   'Address': '421 South Maple Street',
#   'City': 'Garnett',
#   'County': 'Anderson',
#   'State': 'Kansas',
#   'Status': 'Open',
#   'Latitude': 38.2798769950001,
#   'Longitude': -95.250338654,
#   'Beds': 41,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 7567860,
#   'Name': 'Kearny County Hospital',
#   'Address': '500 Thorpe Street',
#   'City': 'Lakin',
#   'County': 'Kearny',
#   'State': 'Kansas',
#   'Status': 'Open',
#   'Latitude': 37.9465932690001,
#   'Longitude': -101.251929912,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 7767467,
#   'Name': 'Ottawa County Health Center',
#   'Address': '215 E 8Th Street',
#   'City': 'Minneapolis',
#   'County': 'Ottawa',
#   'State': 'Kansas',
#   'Status': 'Open',
#   'Latitude': 39.1293319640001,
#   'Longitude': -97.7039442509999,
#   'Beds': 42,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 3502492,
#   'Name': 'Beth Israel Deaconess Hospital - Needham',
#   'Address': '148 Chestnut Street',
#   'City': 'Needham',
#   'County': 'Norfolk',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.2771000000001,
#   'Longitude': -71.2368999999999,
#   'Beds': 58,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12402745,
#   'Name': 'Vibra Hospital Of Southwestern Massachusetts',
#   'Address': '4499 Acushnet Avenue',
#   'City': 'New Bedford',
#   'County': 'Bristol',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 41.740725232,
#   'Longitude': -70.945753607,
#   'Beds': 90,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 4002062,
#   'Name': 'Norwood Hospital',
#   'Address': '800 Washington Road',
#   'City': 'Norwood',
#   'County': 'Norfolk',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.1890000000001,
#   'Longitude': -71.2021,
#   'Beds': 215,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 12602537,
#   'Name': 'Spaulding Rehabilitation Hospital Cape Cod',
#   'Address': '311 Service Road',
#   'City': 'Sandwich',
#   'County': 'Barnstable',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 41.7329844970001,
#   'Longitude': -70.4681028369999,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 6702143,
#   'Name': 'Cambridge Health Alliance - Somerville Campus',
#   'Address': '230 Highland Avenue',
#   'City': 'Somerville',
#   'County': 'Middlesex',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.39,
#   'Longitude': -71.1093999999999,
#   'Beds': 124,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12701104,
#   'Name': "Shriners' Hospital For Children",
#   'Address': '516 Carew St',
#   'City': 'Springfield',
#   'County': 'Hampden',
#   'State': 'Massachusetts',
#   'Status': 'Open',
#   'Latitude': 42.121315027,
#   'Longitude': -72.59237295,
#   'Beds': 40,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 372903,
#   'Name': 'Mercy Hospital Fort Smith',
#   'Address': '7301 Rogers Avenue',
#   'City': 'Fort Smith',
#   'County': 'Sebastian',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.355865991,
#   'Longitude': -94.352054967,
#   'Beds': 336,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 7472901,
#   'Name': 'Healthsouth Rehabilitation Hospital Of Fort Smith',
#   'Address': '1401 South J Street',
#   'City': 'Fort Smith',
#   'County': 'Sebastian',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.3739403050001,
#   'Longitude': -94.4187544819999,
#   'Beds': 80,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 9700000,
#   'Name': 'White County Medical Center - South Campus',
#   'Address': '1200 South Main Street',
#   'City': 'Searcy',
#   'County': 'White',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.2340944110001,
#   'Longitude': -91.731074311,
#   'Beds': 193,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 10172143,
#   'Name': 'White County Medical Center - North Campus',
#   'Address': '3214 East Race Avenue',
#   'City': 'Searcy',
#   'County': 'White',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.2518860440001,
#   'Longitude': -91.697001131,
#   'Beds': 286,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 10272834,
#   'Name': 'River Valley Medical Center',
#   'Address': '200 North Third Street',
#   'City': 'Dardanelle',
#   'County': 'Yell',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.220476139,
#   'Longitude': -93.157298166,
#   'Beds': 35,
#   'Trauma': 'Level Iv',
#   'Helipad': 'N'},
#  {'Id': 2271923,
#   'Name': 'Baptist Health Medical Center - Arkadelphia',
#   'Address': '3050 Twin Rivers Drive',
#   'City': 'Arkadelphia',
#   'County': 'Clark',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.1229135660001,
#   'Longitude': -93.088824163,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 872616,
#   'Name': 'Mercy Hospital Berryville',
#   'Address': '214 Carter Street',
#   'City': 'Berryville',
#   'County': 'Carroll',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.359062103,
#   'Longitude': -93.551825772,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 1072632,
#   'Name': 'Eureka Springs Hospital',
#   'Address': '24 Norris Street',
#   'City': 'Eureka Springs',
#   'County': 'Carroll',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.400163789,
#   'Longitude': -93.744235921,
#   'Beds': 22,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 2871653,
#   'Name': 'Southeast Rehabilitation Hospital',
#   'Address': '2729A Hwy 65 & 82 S',
#   'City': 'Lake Village',
#   'County': 'Chicot',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 33.306293968,
#   'Longitude': -91.289589924,
#   'Beds': 15,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 671671,
#   'Name': 'Bradley County Medical Center',
#   'Address': '404 South Bradley Street',
#   'City': 'Warren',
#   'County': 'Bradley',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 33.6103641340001,
#   'Longitude': -92.059254885,
#   'Beds': 35,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 8872455,
#   'Name': 'Five River Medical Center',
#   'Address': '2801 Medical Center Drive',
#   'City': 'Pocahontas',
#   'County': 'Randolph',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.2897602730001,
#   'Longitude': -90.99738763,
#   'Beds': 50,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 2571742,
#   'Name': 'Dallas County Medical Center',
#   'Address': '201 North Clifton Street',
#   'City': 'Fordyce',
#   'County': 'Dallas',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 33.81085539,
#   'Longitude': -92.425587644,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 6171701,
#   'Name': 'Ouachita Co. Medical Center',
#   'Address': '638 California Avenue',
#   'City': 'Camden',
#   'County': 'Ouachita',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 33.5758211300001,
#   'Longitude': -92.8367393299999,
#   'Beds': 100,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 572601,
#   'Name': 'North Arkansas Regional Medical Center',
#   'Address': '620 North Willow',
#   'City': 'Harrison',
#   'County': 'Boone',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.2365313550001,
#   'Longitude': -93.1091393739999,
#   'Beds': 174,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 1672560,
#   'Name': 'Stone County Medical Center',
#   'Address': '2106 East Main Street, Highway 14 East',
#   'City': 'Mountain View',
#   'County': 'Stone',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.856583126,
#   'Longitude': -92.0828645349999,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 2372454,
#   'Name': 'Piggott Community Hospital',
#   'Address': '1206 Gordon Duckworth Drive',
#   'City': 'Piggott',
#   'County': 'Clay',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.390119473,
#   'Longitude': -90.20483796,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 1372543,
#   'Name': 'Baptist Health - Heber Springs',
#   'Address': '1800 Bypass Road',
#   'City': 'Heber Springs',
#   'County': 'Cleburne',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.488569576,
#   'Longitude': -92.057981141,
#   'Beds': 25,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 2472110,
#   'Name': 'St. Vincent Morrilton',
#   'Address': '4 Hospital Drive',
#   'City': 'Morrilton',
#   'County': 'Conway',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 35.168014912,
#   'Longitude': -92.721351317,
#   'Beds': 35,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 3072205,
#   'Name': 'Uams Medical Center',
#   'Address': '4301 West Markham Street',
#   'City': 'Little Rock',
#   'County': 'Pulaski',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.7490251460001,
#   'Longitude': -92.320137314,
#   'Beds': 400,
#   'Trauma': 'Level I',
#   'Helipad': 'Y'},
#  {'Id': 5000000,
#   'Name': 'Baptist Health Medical Center - North Little Rock',
#   'Address': '3333 Springhill Drive',
#   'City': 'Little Rock',
#   'County': 'Pulaski',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.7836548870001,
#   'Longitude': -92.223409163,
#   'Beds': 248,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 6972113,
#   'Name': 'United Methodist Behavioral Health Systems',
#   'Address': '1601 Murphy Drive',
#   'City': 'Maumelle',
#   'County': 'Pulaski',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.8764356660001,
#   'Longitude': -92.394413249,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 1971901,
#   'Name': 'Leo N. Levi National Arthritis Hospital',
#   'Address': '300 Prospect Avenue',
#   'City': 'Hot Springs',
#   'County': 'Garland',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.5098970650001,
#   'Longitude': -93.057577489,
#   'Beds': 89,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5971913,
#   'Name': 'Chi St Vincent Hospital Hot Springs',
#   'Address': '300 Werner Street',
#   'City': 'Hot Springs',
#   'County': 'Garland',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.46802567,
#   'Longitude': -93.066270414,
#   'Beds': 289,
#   'Trauma': 'Level Ii',
#   'Helipad': 'Y'},
#  {'Id': 6600000,
#   'Name': 'Baptist Health Medical Center - Hot Spring County',
#   'Address': '1001 Schneider Drive',
#   'City': 'Malvern',
#   'County': 'Hot Spring',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.358774038,
#   'Longitude': -92.785888401,
#   'Beds': 72,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 3971603,
#   'Name': 'Arkansas Dept. Of Correction-Diagnostic Unit',
#   'Address': '7500 Corrections Circle',
#   'City': 'Pine Bluff',
#   'County': 'Jefferson',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.2221914250001,
#   'Longitude': -92.082686048,
#   'Beds': 27,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 6871603,
#   'Name': 'Jefferson Regional Medical Center',
#   'Address': '1600 West 40Th Avenue',
#   'City': 'Pine Bluff',
#   'County': 'Jefferson',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 34.1877346910001,
#   'Longitude': -92.017680195,
#   'Beds': 471,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 2772703,
#   'Name': 'Healthsouth Rehabilitation Hospital',
#   'Address': '153 East Monte Painter Drive',
#   'City': 'Fayetteville',
#   'County': 'Washington',
#   'State': 'Arkansas',
#   'Status': 'Open',
#   'Latitude': 36.109099384,
#   'Longitude': -94.154845038,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 331404,
#   'Name': 'Memorial Health Univ Med Cen, Inc',
#   'Address': '4700 Waters Avenue',
#   'City': 'Savannah',
#   'County': 'Chatham',
#   'State': 'Georgia',
#   'Status': 'Open',
# ...
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 36.4084534690001,
#   'Longitude': -78.984895239,
#   'Beds': 110,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 5327344,
#   'Name': 'Chatham Hospital, Inc.',
#   'Address': '475 Progress Boulevard',
#   'City': 'Siler City',
#   'County': 'Chatham',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.722954498,
#   'Longitude': -79.420855358,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 928906,
#   'Name': 'Erlanger Murphy Medical Center',
#   'Address': '3990 East Us Hwy 64',
#   'City': 'Murphy',
#   'County': 'Cherokee',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.072712896,
#   'Longitude': -83.966662408,
#   'Beds': 191,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 10228359,
#   'Name': 'Southeastern Regional Medical Center',
#   'Address': '300 West 27Th St',
#   'City': 'Lumberton',
#   'County': 'Robeson',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 34.636910793,
#   'Longitude': -79.0121295329999,
#   'Beds': 452,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5228646,
#   'Name': 'Charles A. Cannon, Jr. Memorial Hospital',
#   'Address': '434 Hospital Drive',
#   'City': 'Linville',
#   'County': 'Avery',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 36.0603179240001,
#   'Longitude': -81.8893571149999,
#   'Beds': 50,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 8428461,
#   'Name': 'J. Arthur Dosher Memorial Hospital',
#   'Address': '924 Howe St',
#   'City': 'Southport',
#   'County': 'Brunswick',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 33.92966195,
#   'Longitude': -78.0215903119999,
#   'Beds': 100,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 4028813,
#   'Name': 'Carepartners Rehabilitation Hospital',
#   'Address': '68 Sweeten Creek Road',
#   'City': 'Asheville',
#   'County': 'Buncombe',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.5622710920001,
#   'Longitude': -82.53131981,
#   'Beds': 80,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 7228655,
#   'Name': 'Carolinas Healthcare System Blue Ridge',
#   'Address': '2201 South Sterling St',
#   'City': 'Morganton',
#   'County': 'Burke',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.726391173,
#   'Longitude': -81.654492279,
#   'Beds': 315,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 3928302,
#   'Name': 'Cape Fear Valley Medical Center',
#   'Address': '1638 Owen Drive',
#   'City': 'Fayetteville',
#   'County': 'Cumberland',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.0318387250001,
#   'Longitude': -78.9330536849999,
#   'Beds': 600,
#   'Trauma': 'Level Iii',
#   'Helipad': 'Y'},
#  {'Id': 14128170,
#   'Name': 'Atrium Health- Anson',
#   'Address': '2301 Us Highway 74 West',
#   'City': 'Wadesboro',
#   'County': 'Anson',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 34.977721882,
#   'Longitude': -80.1100856209999,
#   'Beds': 15,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 14328086,
#   'Name': 'Carolinas Continuecare At Kings Mountain',
#   'Address': '706 West King Street',
#   'City': 'Kings Mountain',
#   'County': 'Cleveland',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.241865106,
#   'Longitude': -81.3565487499999,
#   'Beds': 28,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 14528025,
#   'Name': 'Carolinas Rehabilitation - Northeast',
#   'Address': '487 Lake Concord Road',
#   'City': 'Concord',
#   'County': 'Cabarrus',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.442816061,
#   'Longitude': -80.6008436509999,
#   'Beds': 40,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 14628376,
#   'Name': 'Firsthealth Moore Regional Hospital - Hoke Campus',
#   'Address': '6408 Fayetteville Road',
#   'City': 'Raeford',
#   'County': 'Hoke',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 35.02100061,
#   'Longitude': -79.149218661,
#   'Beds': 8,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 15127401,
#   'Name': 'Select Specialty Hospital - Greensboro',
#   'Address': '1200 North Elm Street',
#   'City': 'Greensboro',
#   'County': 'Guilford',
#   'State': 'North Carolina',
#   'Status': 'Open',
#   'Latitude': 36.091017988,
#   'Longitude': -79.7860481129999,
#   'Beds': 30,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 1158784,
#   'Name': 'Mountrail County Medical Center',
#   'Address': '615 6Th St Se',
#   'City': 'Stanley',
#   'County': 'Mountrail',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 48.311293849,
#   'Longitude': -102.380421892,
#   'Beds': 11,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 2558474,
#   'Name': 'Oakes Community Hospital',
#   'Address': '1200 N 7Th St',
#   'City': 'Oakes',
#   'County': 'Dickey',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 46.1503806630001,
#   'Longitude': -98.088894282,
#   'Beds': 20,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 5058402,
#   'Name': 'North Dakota State Hospital',
#   'Address': '2605 Circle Dr',
#   'City': 'Jamestown',
#   'County': 'Stutsman',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 46.8843327650001,
#   'Longitude': -98.684748531,
#   'Beds': 140,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 4058324,
#   'Name': 'Towner County Medical Center',
#   'Address': 'Hwy 281 N',
#   'City': 'Cando',
#   'County': 'Towner',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 48.493022002,
#   'Longitude': -99.211136129,
#   'Beds': 20,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 1958257,
#   'Name': 'Sanford Mayville',
#   'Address': '42 6Th Avenue Se',
#   'City': 'Mayville',
#   'County': 'Traill',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 47.500743275,
#   'Longitude': -97.316907866,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 2658367,
#   'Name': 'Presentation Medical Center',
#   'Address': '213 Second Ave Ne',
#   'City': 'Rolla',
#   'County': 'Rolette',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 48.8626424080001,
#   'Longitude': -99.615557842,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 4258801,
#   'Name': 'Chi St Alexius Health Williston',
#   'Address': '1301 15Th Ave W',
#   'City': 'Williston',
#   'County': 'Williams',
#   'State': 'North Dakota',
#   'Status': 'Open',
#   'Latitude': 48.1559507640001,
#   'Longitude': -103.646013698,
#   'Beds': 25,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 182870806,
#   'Name': 'Regions Behavioral Hospital',
#   'Address': '8416 Cumberland',
#   'City': 'Baton Rouge',
#   'County': 'East Baton Rouge',
#   'State': 'Louisiana',
#   'Status': 'Open',
#   'Latitude': 30.4447976340001,
#   'Longitude': -91.097562355,
#   'Beds': 24,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5932821,
#   'Name': 'Central Florida Behavioral Hospital',
#   'Address': '6601 Central Florida Pkwy',
#   'City': 'Orlando',
#   'County': 'Orange',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.409114054,
#   'Longitude': -81.469593393,
#   'Beds': 174,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 6468729,
#   'Name': 'Avera Creighton Hospital',
#   'Address': '1503 Main St',
#   'City': 'Creighton',
#   'County': 'Knox',
#   'State': 'Nebraska',
#   'Status': 'Open',
#   'Latitude': 42.4659183430001,
#   'Longitude': -97.9168979359999,
#   'Beds': 23,
#   'Trauma': 'Level Iv',
#   'Helipad': 'Y'},
#  {'Id': 10232803,
#   'Name': 'Adventhealth Orlando',
#   'Address': '601 E Rollins St',
#   'City': 'Orlando',
#   'County': 'Orange',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.574414351,
#   'Longitude': -81.369996427,
#   'Beds': 1368,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 11832822,
#   'Name': 'Adventhealth East Orlando',
#   'Address': '7727 Lake Underhill Rd',
#   'City': 'Orlando',
#   'County': 'Orange',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.5399802540001,
#   'Longitude': -81.281540116,
#   'Beds': 295,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 15534761,
#   'Name': 'Health Central',
#   'Address': '10000 W Colonial Dr',
#   'City': 'Ocoee',
#   'County': 'Orange',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.549662416,
#   'Longitude': -81.5276599279999,
#   'Beds': 211,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 34232803,
#   'Name': 'Select Specialty Hospital - Orlando North',
#   'Address': '2250 Bedford Rd',
#   'City': 'Orlando',
#   'County': 'Orange',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.5722967250001,
#   'Longitude': -81.370441796,
#   'Beds': 35,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 38334769,
#   'Name': 'St Cloud Regional Medical Center',
#   'Address': '2906 17Th St',
#   'City': 'Saint Cloud',
#   'County': 'Osceola',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.24362232,
#   'Longitude': -81.3028067239999,
#   'Beds': 84,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 3333435,
#   'Name': 'Bethesda Hospital East',
#   'Address': '2815 S Seacrest Blvd',
#   'City': 'Boynton Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.5050572330001,
#   'Longitude': -80.070563971,
#   'Beds': 401,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 14133401,
#   'Name': 'Good Samaritan Medical Center',
#   'Address': '1309 N Flagler Dr',
#   'City': 'West Palm Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.7254617310001,
#   'Longitude': -80.0518812669999,
#   'Beds': 333,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 6833407,
#   'Name': 'Jfk Medical Center North Campus',
#   'Address': '2201 45Th St',
#   'City': 'West Palm Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.761323589,
#   'Longitude': -80.087872693,
#   'Beds': 245,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 19933418,
#   'Name': 'Kindred Hospital Palm Beaches',
#   'Address': '5555 W Blue Heron Blvd',
#   'City': 'Riviera Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.7829789510001,
#   'Longitude': -80.1104593429999,
#   'Beds': 70,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 39133407,
#   'Name': "St Mary'S Medical Center",
#   'Address': '901 45Th St',
#   'City': 'West Palm Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.755871143,
#   'Longitude': -80.0624620309999,
#   'Beds': 460,
#   'Trauma': 'Level I',
#   'Helipad': 'Y'},
#  {'Id': 42033428,
#   'Name': 'West Boca Medical Center',
#   'Address': '21644 State Rd 7',
#   'City': 'Boca Raton',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.3561962630001,
#   'Longitude': -80.199188577,
#   'Beds': 195,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 42633410,
#   'Name': 'West Palm Beach Va Medical Center',
#   'Address': '7305 N Military Trail',
#   'City': 'West Palm Beach',
#   'County': 'Palm Beach',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.784928027,
#   'Longitude': -80.112475236,
#   'Beds': 236,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12934689,
#   'Name': 'Adventhealth North Pinellas',
#   'Address': '1395 S Pinellas Ave',
#   'City': 'Tarpon Springs',
#   'County': 'Pinellas',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.132933816,
#   'Longitude': -82.75778618,
#   'Beds': 168,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 26833756,
#   'Name': 'Morton Plant Hospital',
#   'Address': '300 Pinellas St',
#   'City': 'Clearwater',
#   'County': 'Pinellas',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 27.952816747,
#   'Longitude': -82.803696838,
#   'Beds': 613,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 39333710,
#   'Name': 'St Petersburg General Hospital',
#   'Address': '6500 38Th Ave N',
#   'City': 'Saint Petersburg',
#   'County': 'Pinellas',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 27.8054392110001,
#   'Longitude': -82.727538744,
#   'Beds': 215,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 12233872,
#   'Name': 'Adventhealth Sebring',
#   'Address': '4200 Sun N Lake Blvd',
#   'City': 'Sebring',
#   'County': 'Highlands',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 27.539751274,
#   'Longitude': -81.5092099839999,
#   'Beds': 147,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 2997301,
#   'Name': 'Oregon State Hospital- Salem',
#   'Address': '2600 Center Street Ne',
#   'City': 'Ne Salem',
#   'County': 'Marion',
#   'State': 'Oregon',
#   'Status': 'Open',
#   'Latitude': 44.9390394760001,
#   'Longitude': -123.004577062,
#   'Beds': 27,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 13233613,
#   'Name': 'Adventhealth Tampa',
#   'Address': '3100 E Fletcher Ave',
#   'City': 'Tampa',
#   'County': 'Hillsborough',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.0710959690001,
#   'Longitude': -82.4240611769999,
#   'Beds': 365,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 18933612,
#   'Name': "James A Haley Veterans' Hospital",
#   'Address': '13000 Bruce B Downs Blvd',
#   'City': 'Tampa',
#   'County': 'Hillsborough',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.064409101,
#   'Longitude': -82.429277019,
#   'Beds': 93,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 36033612,
#   'Name': 'Shriners Hospitals For Children - Tampa',
#   'Address': '12502 Usf Pine Dr',
#   'City': 'Tampa',
#   'County': 'Hillsborough',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.0615605200001,
#   'Longitude': -82.42284161,
#   'Beds': 60,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 36433563,
#   'Name': 'South Florida Baptist Hospital',
#   'Address': '301 N Alexander St',
#   'City': 'Plant City',
#   'County': 'Hillsborough',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.0156788480001,
#   'Longitude': -82.138929363,
#   'Beds': 147,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 38833558,
#   'Name': "St Joseph'S Hospital North",
#   'Address': '4211 Van Dyke Rd',
#   'City': 'Lutz',
#   'County': 'Hillsborough',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.1295801160001,
#   'Longitude': -82.509675586,
#   'Beds': 108,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 37734609,
#   'Name': 'Springbrook Hospital',
#   'Address': '7007 Grove Rd',
#   'City': 'Brooksville',
#   'County': 'Hernando',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 28.5329355380001,
#   'Longitude': -82.484208672,
#   'Beds': 66,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 32432054,
#   'Name': 'Reception And Medical Center Hospital',
#   'Address': '7765 S County Rd 231',
#   'City': 'Lake Butler',
#   'County': 'Union',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 29.988435252,
#   'Longitude': -82.357635252,
#   'Beds': 133,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 7834233,
#   'Name': 'Doctors Hospital Of Sarasota',
#   'Address': '5731 Bee Ridge Rd',
#   'City': 'Sarasota',
#   'County': 'Sarasota',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 27.3019576310001,
#   'Longitude': -82.453350609,
#   'Beds': 155,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  {'Id': 5533990,
#   'Name': 'Cape Coral Hospital',
#   'Address': '636 Del Prado Blvd',
#   'City': 'Cape Coral',
#   'County': 'Lee',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 26.6392051770001,
#   'Longitude': -81.942022498,
#   'Beds': 291,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 11532721,
#   'Name': 'Adventhealth Deland',
#   'Address': '701 W Plymouth Ave',
#   'City': 'Deland',
#   'County': 'Volusia',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 29.04365274,
#   'Longitude': -81.3173440369999,
#   'Beds': 164,
#   'Trauma': 'Not Available',
#   'Helipad': 'Y'},
#  {'Id': 13032176,
#   'Name': 'Florida Hospital Oceanside',
#   'Address': '264 S Atlantic Ave',
#   'City': 'Ormond Beach',
#   'County': 'Volusia',
#   'State': 'Florida',
#   'Status': 'Open',
#   'Latitude': 29.284636683,
#   'Longitude': -81.03686657,
#   'Beds': 80,
#   'Trauma': 'Not Available',
#   'Helipad': 'N'},
#  ...]

# %%
rows
# Out:
# [<sqlite3.Row at 0x19d4d7fcbe0>,
#  <sqlite3.Row at 0x19d4d7fda20>,
#  <sqlite3.Row at 0x19d4d7fd150>,
#  <sqlite3.Row at 0x19d4ee5ae30>,
#  <sqlite3.Row at 0x19d4ee5b370>,
#  <sqlite3.Row at 0x19d4ee5ada0>,
#  <sqlite3.Row at 0x19d4ee5b190>,
#  <sqlite3.Row at 0x19d4ee5b1f0>,
#  <sqlite3.Row at 0x19d4ee5ba00>,
#  <sqlite3.Row at 0x19d4ee5b8b0>,
#  <sqlite3.Row at 0x19d4ee5b880>,
#  <sqlite3.Row at 0x19d4ee5b220>,
#  <sqlite3.Row at 0x19d4ee5ac80>,
#  <sqlite3.Row at 0x19d4ee5acb0>,
#  <sqlite3.Row at 0x19d4ee5ad40>,
#  <sqlite3.Row at 0x19d4ee5b310>,
#  <sqlite3.Row at 0x19d4ee5ace0>,
#  <sqlite3.Row at 0x19d4ee5bee0>,
#  <sqlite3.Row at 0x19d4ee5b1c0>,
#  <sqlite3.Row at 0x19d4ee5b160>,
#  <sqlite3.Row at 0x19d4ee5b100>,
#  <sqlite3.Row at 0x19d4ee5b0d0>,
#  <sqlite3.Row at 0x19d4ee5b0a0>,
#  <sqlite3.Row at 0x19d4ee5a8c0>,
#  <sqlite3.Row at 0x19d4ee5abf0>,
#  <sqlite3.Row at 0x19d4ee5ad70>,
#  <sqlite3.Row at 0x19d4ee5bfa0>,
#  <sqlite3.Row at 0x19d4ee5b2e0>,
#  <sqlite3.Row at 0x19d4ee5aa70>,
#  <sqlite3.Row at 0x19d4ee5b280>,
#  <sqlite3.Row at 0x19d4ee5aa10>,
#  <sqlite3.Row at 0x19d4ee5ba60>,
#  <sqlite3.Row at 0x19d4ee5aec0>,
#  <sqlite3.Row at 0x19d4ee5ae90>,
#  <sqlite3.Row at 0x19d4ee5bb20>,
#  <sqlite3.Row at 0x19d4ee5b430>,
#  <sqlite3.Row at 0x19d4ee5b4f0>,
#  <sqlite3.Row at 0x19d4ee5b700>,
#  <sqlite3.Row at 0x19d4ee5ab90>,
#  <sqlite3.Row at 0x19d4ee5abc0>,
#  <sqlite3.Row at 0x19d4ee5ab00>,
#  <sqlite3.Row at 0x19d4ee5bf40>,
#  <sqlite3.Row at 0x19d4ee5a920>,
#  <sqlite3.Row at 0x19d4ee5b2b0>,
#  <sqlite3.Row at 0x19d4ee5aa40>,
#  <sqlite3.Row at 0x19d4ee5a9b0>,
#  <sqlite3.Row at 0x19d4ee5b4c0>,
#  <sqlite3.Row at 0x19d4ee5ae60>,
#  <sqlite3.Row at 0x19d4ee5b400>,
#  <sqlite3.Row at 0x19d4ee5af80>,
#  <sqlite3.Row at 0x19d4ee5b340>,
#  <sqlite3.Row at 0x19d4ee5b490>,
#  <sqlite3.Row at 0x19d4ee5b520>,
#  <sqlite3.Row at 0x19d4ee5b850>,
#  <sqlite3.Row at 0x19d4ee5bf10>,
#  <sqlite3.Row at 0x19d4ee5a8f0>,
#  <sqlite3.Row at 0x19d4ee5ba90>,
#  <sqlite3.Row at 0x19d4ee5bac0>,
#  <sqlite3.Row at 0x19d4ee5baf0>,
#  <sqlite3.Row at 0x19d4ee5bcd0>,
#  <sqlite3.Row at 0x19d4ee5bd00>,
#  <sqlite3.Row at 0x19d4ee5bd30>,
#  <sqlite3.Row at 0x19d4ee5bd60>,
#  <sqlite3.Row at 0x19d4ee5bd90>,
#  <sqlite3.Row at 0x19d4ee5bdc0>,
#  <sqlite3.Row at 0x19d4ee5afb0>,
#  <sqlite3.Row at 0x19d4ee5afe0>,
#  <sqlite3.Row at 0x19d4ee5b010>,
#  <sqlite3.Row at 0x19d4ee5b040>,
#  <sqlite3.Row at 0x19d4ee5b070>,
#  <sqlite3.Row at 0x19d4ee5bb50>,
#  <sqlite3.Row at 0x19d4ee5bb80>,
#  <sqlite3.Row at 0x19d4ee5bbb0>,
#  <sqlite3.Row at 0x19d4ee5bbe0>,
#  <sqlite3.Row at 0x19d4ee5bc10>,
#  <sqlite3.Row at 0x19d4ee5bc40>,
#  <sqlite3.Row at 0x19d4ee5bc70>,
#  <sqlite3.Row at 0x19d4ee5bca0>,
#  <sqlite3.Row at 0x19d4ee5b9a0>,
#  <sqlite3.Row at 0x19d4ee5b970>,
#  <sqlite3.Row at 0x19d4ee5b940>,
#  <sqlite3.Row at 0x19d4ee5b910>,
#  <sqlite3.Row at 0x19d4ee5b8e0>,
#  <sqlite3.Row at 0x19d4ee5b130>,
#  <sqlite3.Row at 0x19d4ee5a980>,
#  <sqlite3.Row at 0x19d4ee5ad10>,
#  <sqlite3.Row at 0x19d4f1b4040>,
#  <sqlite3.Row at 0x19d4f1b4070>,
#  <sqlite3.Row at 0x19d4f1b40a0>,
#  <sqlite3.Row at 0x19d4f1b40d0>,
#  <sqlite3.Row at 0x19d4f1b4100>,
#  <sqlite3.Row at 0x19d4f1b4130>,
#  <sqlite3.Row at 0x19d4f1b4160>,
#  <sqlite3.Row at 0x19d4f1b4190>,
#  <sqlite3.Row at 0x19d4f1b41c0>,
#  <sqlite3.Row at 0x19d4f1b41f0>,
#  <sqlite3.Row at 0x19d4f1b4220>,
#  <sqlite3.Row at 0x19d4f1b4250>,
#  <sqlite3.Row at 0x19d4f1b4280>,
#  <sqlite3.Row at 0x19d4f1b42b0>,
#  <sqlite3.Row at 0x19d4f1b42e0>,
#  <sqlite3.Row at 0x19d4f1b4310>,
#  <sqlite3.Row at 0x19d4f1b4340>,
#  <sqlite3.Row at 0x19d4f1b4370>,
#  <sqlite3.Row at 0x19d4f1b43a0>,
#  <sqlite3.Row at 0x19d4f1b43d0>,
#  <sqlite3.Row at 0x19d4f1b4400>,
#  <sqlite3.Row at 0x19d4f1b4430>,
#  <sqlite3.Row at 0x19d4f1b4460>,
#  <sqlite3.Row at 0x19d4f1b4490>,
#  <sqlite3.Row at 0x19d4f1b44c0>,
#  <sqlite3.Row at 0x19d4f1b44f0>,
#  <sqlite3.Row at 0x19d4f1b4520>,
#  <sqlite3.Row at 0x19d4f1b4550>,
#  <sqlite3.Row at 0x19d4f1b4580>,
#  <sqlite3.Row at 0x19d4f1b45b0>,
#  <sqlite3.Row at 0x19d4f1b45e0>,
#  <sqlite3.Row at 0x19d4f1b4610>,
#  <sqlite3.Row at 0x19d4f1b4640>,
#  <sqlite3.Row at 0x19d4f1b4670>,
#  <sqlite3.Row at 0x19d4f1b46a0>,
#  <sqlite3.Row at 0x19d4f1b46d0>,
#  <sqlite3.Row at 0x19d4f1b4700>,
#  <sqlite3.Row at 0x19d4f1b4730>,
#  <sqlite3.Row at 0x19d4f1b4760>,
#  <sqlite3.Row at 0x19d4f1b4790>,
#  <sqlite3.Row at 0x19d4f1b47c0>,
#  <sqlite3.Row at 0x19d4f1b47f0>,
#  <sqlite3.Row at 0x19d4f1b4820>,
#  <sqlite3.Row at 0x19d4f1b4850>,
#  <sqlite3.Row at 0x19d4f1b4880>,
#  <sqlite3.Row at 0x19d4f1b48b0>,
#  <sqlite3.Row at 0x19d4f1b48e0>,
#  <sqlite3.Row at 0x19d4f1b4910>,
#  <sqlite3.Row at 0x19d4f1b4940>,
#  <sqlite3.Row at 0x19d4f1b4970>,
#  <sqlite3.Row at 0x19d4f1b49a0>,
#  <sqlite3.Row at 0x19d4f1b49d0>,
#  <sqlite3.Row at 0x19d4f1b4a00>,
#  <sqlite3.Row at 0x19d4f1b4a30>,
#  <sqlite3.Row at 0x19d4f1b4a60>,
#  <sqlite3.Row at 0x19d4f1b4a90>,
#  <sqlite3.Row at 0x19d4f1b4ac0>,
#  <sqlite3.Row at 0x19d4f1b4af0>,
#  <sqlite3.Row at 0x19d4f1b4b20>,
#  <sqlite3.Row at 0x19d4f1b4b50>,
#  <sqlite3.Row at 0x19d4f1b4b80>,
#  <sqlite3.Row at 0x19d4f1b4bb0>,
#  <sqlite3.Row at 0x19d4f1b4be0>,
#  <sqlite3.Row at 0x19d4f1b4c10>,
#  <sqlite3.Row at 0x19d4f1b4c40>,
#  <sqlite3.Row at 0x19d4f1b4c70>,
#  <sqlite3.Row at 0x19d4f1b4ca0>,
#  <sqlite3.Row at 0x19d4f1b4cd0>,
#  <sqlite3.Row at 0x19d4f1b4d00>,
#  <sqlite3.Row at 0x19d4f1b4d30>,
#  <sqlite3.Row at 0x19d4f1b4d60>,
#  <sqlite3.Row at 0x19d4f1b4d90>,
#  <sqlite3.Row at 0x19d4f1b4dc0>,
#  <sqlite3.Row at 0x19d4f1b4df0>,
#  <sqlite3.Row at 0x19d4f1b4e20>,
#  <sqlite3.Row at 0x19d4f1b4e50>,
#  <sqlite3.Row at 0x19d4f1b4e80>,
#  <sqlite3.Row at 0x19d4f1b4eb0>,
#  <sqlite3.Row at 0x19d4f1b4ee0>,
#  <sqlite3.Row at 0x19d4f1b4f10>,
#  <sqlite3.Row at 0x19d4f1b4f40>,
#  <sqlite3.Row at 0x19d4f1b4f70>,
#  <sqlite3.Row at 0x19d4f1b4fa0>,
#  <sqlite3.Row at 0x19d4f1b4fd0>,
#  <sqlite3.Row at 0x19d4f1b5000>,
#  <sqlite3.Row at 0x19d4f1b5030>,
#  <sqlite3.Row at 0x19d4f1b5060>,
#  <sqlite3.Row at 0x19d4f1b5090>,
#  <sqlite3.Row at 0x19d4f1b50c0>,
#  <sqlite3.Row at 0x19d4f1b50f0>,
#  <sqlite3.Row at 0x19d4f1b5120>,
#  <sqlite3.Row at 0x19d4f1b5150>,
#  <sqlite3.Row at 0x19d4f1b5180>,
#  <sqlite3.Row at 0x19d4f1b51b0>,
#  <sqlite3.Row at 0x19d4f1b51e0>,
#  <sqlite3.Row at 0x19d4f1b5210>,
#  <sqlite3.Row at 0x19d4f1b5240>,
#  <sqlite3.Row at 0x19d4f1b5270>,
#  <sqlite3.Row at 0x19d4f1b52a0>,
#  <sqlite3.Row at 0x19d4f1b52d0>,
#  <sqlite3.Row at 0x19d4f1b5300>,
#  <sqlite3.Row at 0x19d4f1b5330>,
#  <sqlite3.Row at 0x19d4f1b5360>,
#  <sqlite3.Row at 0x19d4f1b5390>,
#  <sqlite3.Row at 0x19d4f1b53c0>,
#  <sqlite3.Row at 0x19d4f1b53f0>,
#  <sqlite3.Row at 0x19d4f1b5420>,
#  <sqlite3.Row at 0x19d4f1b5450>,
#  <sqlite3.Row at 0x19d4f1b5480>,
#  <sqlite3.Row at 0x19d4f1b54b0>,
#  <sqlite3.Row at 0x19d4f1b54e0>,
#  <sqlite3.Row at 0x19d4f1b5510>,
#  <sqlite3.Row at 0x19d4f1b5540>,
#  <sqlite3.Row at 0x19d4f1b5570>,
#  <sqlite3.Row at 0x19d4f1b55a0>,
#  <sqlite3.Row at 0x19d4f1b55d0>,
#  <sqlite3.Row at 0x19d4f1b5600>,
#  <sqlite3.Row at 0x19d4f1b5630>,
#  <sqlite3.Row at 0x19d4f1b5660>,
#  <sqlite3.Row at 0x19d4f1b5690>,
#  <sqlite3.Row at 0x19d4f1b56c0>,
#  <sqlite3.Row at 0x19d4f1b56f0>,
#  <sqlite3.Row at 0x19d4f1b5720>,
#  <sqlite3.Row at 0x19d4f1b5750>,
#  <sqlite3.Row at 0x19d4f1b5780>,
#  <sqlite3.Row at 0x19d4f1b57b0>,
#  <sqlite3.Row at 0x19d4f1b57e0>,
#  <sqlite3.Row at 0x19d4f1b5810>,
#  <sqlite3.Row at 0x19d4f1b5840>,
#  <sqlite3.Row at 0x19d4f1b5870>,
#  <sqlite3.Row at 0x19d4f1b58a0>,
#  <sqlite3.Row at 0x19d4f1b58d0>,
#  <sqlite3.Row at 0x19d4f1b5900>,
#  <sqlite3.Row at 0x19d4f1b5930>,
#  <sqlite3.Row at 0x19d4f1b5960>,
#  <sqlite3.Row at 0x19d4f1b5990>,
#  <sqlite3.Row at 0x19d4f1b59c0>,
#  <sqlite3.Row at 0x19d4f1b59f0>,
#  <sqlite3.Row at 0x19d4f1b5a20>,
#  <sqlite3.Row at 0x19d4f1b5a50>,
#  <sqlite3.Row at 0x19d4f1b5a80>,
#  <sqlite3.Row at 0x19d4f1b5ab0>,
#  <sqlite3.Row at 0x19d4f1b5ae0>,
#  <sqlite3.Row at 0x19d4f1b5b10>,
#  <sqlite3.Row at 0x19d4f1b5b40>,
#  <sqlite3.Row at 0x19d4f1b5b70>,
#  <sqlite3.Row at 0x19d4f1b5ba0>,
#  <sqlite3.Row at 0x19d4f1b5bd0>,
#  <sqlite3.Row at 0x19d4f1b5c00>,
#  <sqlite3.Row at 0x19d4f1b5c30>,
#  <sqlite3.Row at 0x19d4f1b5c60>,
#  <sqlite3.Row at 0x19d4f1b5c90>,
#  <sqlite3.Row at 0x19d4f1b5cc0>,
#  <sqlite3.Row at 0x19d4f1b5cf0>,
#  <sqlite3.Row at 0x19d4f1b5d20>,
#  <sqlite3.Row at 0x19d4f1b5d50>,
#  <sqlite3.Row at 0x19d4f1b5d80>,
#  <sqlite3.Row at 0x19d4f1b5db0>,
#  <sqlite3.Row at 0x19d4f1b5de0>,
#  <sqlite3.Row at 0x19d4f1b5e10>,
#  <sqlite3.Row at 0x19d4f1b5e40>,
#  <sqlite3.Row at 0x19d4f1b5e70>,
#  <sqlite3.Row at 0x19d4f1b5ea0>,
#  <sqlite3.Row at 0x19d4f1b5ed0>,
#  <sqlite3.Row at 0x19d4f1b5f00>,
#  <sqlite3.Row at 0x19d4f1b5f30>,
#  <sqlite3.Row at 0x19d4f1b5f60>,
#  <sqlite3.Row at 0x19d4f1b5f90>,
#  <sqlite3.Row at 0x19d4f1b5fc0>,
#  <sqlite3.Row at 0x19d4f1b5ff0>,
#  <sqlite3.Row at 0x19d4f1b6020>,
#  <sqlite3.Row at 0x19d4f1b6050>,
#  <sqlite3.Row at 0x19d4f1b6080>,
#  <sqlite3.Row at 0x19d4f1b60b0>,
#  <sqlite3.Row at 0x19d4f1b60e0>,
#  <sqlite3.Row at 0x19d4f1b6110>,
#  <sqlite3.Row at 0x19d4f1b6140>,
#  <sqlite3.Row at 0x19d4f1b6170>,
#  <sqlite3.Row at 0x19d4f1b61a0>,
#  <sqlite3.Row at 0x19d4f1b61d0>,
#  <sqlite3.Row at 0x19d4f1b6200>,
#  <sqlite3.Row at 0x19d4f1b6230>,
#  <sqlite3.Row at 0x19d4f1b6260>,
#  <sqlite3.Row at 0x19d4f1b6290>,
#  <sqlite3.Row at 0x19d4f1b62c0>,
#  <sqlite3.Row at 0x19d4f1b62f0>,
#  <sqlite3.Row at 0x19d4f1b6320>,
#  <sqlite3.Row at 0x19d4f1b6350>,
#  <sqlite3.Row at 0x19d4f1b6380>,
#  <sqlite3.Row at 0x19d4f1b63b0>,
#  <sqlite3.Row at 0x19d4f1b63e0>,
#  <sqlite3.Row at 0x19d4f1b6410>,
#  <sqlite3.Row at 0x19d4f1b6440>,
#  <sqlite3.Row at 0x19d4f1b6470>,
#  <sqlite3.Row at 0x19d4f1b64a0>,
#  <sqlite3.Row at 0x19d4f1b64d0>,
#  <sqlite3.Row at 0x19d4f1b6500>,
#  <sqlite3.Row at 0x19d4f1b6530>,
#  <sqlite3.Row at 0x19d4f1b6560>,
#  <sqlite3.Row at 0x19d4f1b6590>,
#  <sqlite3.Row at 0x19d4f1b65c0>,
#  <sqlite3.Row at 0x19d4f1b65f0>,
#  <sqlite3.Row at 0x19d4f1b6620>,
#  <sqlite3.Row at 0x19d4f1b6650>,
#  <sqlite3.Row at 0x19d4f1b6680>,
#  <sqlite3.Row at 0x19d4f1b66b0>,
#  <sqlite3.Row at 0x19d4f1b66e0>,
#  <sqlite3.Row at 0x19d4f1b6710>,
#  <sqlite3.Row at 0x19d4f1b6740>,
#  <sqlite3.Row at 0x19d4f1b6770>,
#  <sqlite3.Row at 0x19d4f1b67a0>,
#  <sqlite3.Row at 0x19d4f1b67d0>,
#  <sqlite3.Row at 0x19d4f1b6800>,
#  <sqlite3.Row at 0x19d4f1b6830>,
#  <sqlite3.Row at 0x19d4f1b6860>,
#  <sqlite3.Row at 0x19d4f1b6890>,
#  <sqlite3.Row at 0x19d4f1b68c0>,
#  <sqlite3.Row at 0x19d4f1b68f0>,
#  <sqlite3.Row at 0x19d4f1b6920>,
#  <sqlite3.Row at 0x19d4f1b6950>,
#  <sqlite3.Row at 0x19d4f1b6980>,
#  <sqlite3.Row at 0x19d4f1b69b0>,
#  <sqlite3.Row at 0x19d4f1b69e0>,
#  <sqlite3.Row at 0x19d4f1b6a10>,
#  <sqlite3.Row at 0x19d4f1b6a40>,
#  <sqlite3.Row at 0x19d4f1b6a70>,
#  <sqlite3.Row at 0x19d4f1b6aa0>,
#  <sqlite3.Row at 0x19d4f1b6ad0>,
#  <sqlite3.Row at 0x19d4f1b6b00>,
#  <sqlite3.Row at 0x19d4f1b6b30>,
#  <sqlite3.Row at 0x19d4f1b6b60>,
#  <sqlite3.Row at 0x19d4f1b6b90>,
#  <sqlite3.Row at 0x19d4f1b6bc0>,
#  <sqlite3.Row at 0x19d4f1b6bf0>,
#  <sqlite3.Row at 0x19d4f1b6c20>,
#  <sqlite3.Row at 0x19d4f1b6c50>,
#  <sqlite3.Row at 0x19d4f1b6c80>,
#  <sqlite3.Row at 0x19d4f1b6cb0>,
#  <sqlite3.Row at 0x19d4f1b6ce0>,
#  <sqlite3.Row at 0x19d4f1b6d10>,
#  <sqlite3.Row at 0x19d4f1b6d40>,
#  <sqlite3.Row at 0x19d4f1b6d70>,
#  <sqlite3.Row at 0x19d4f1b6da0>,
#  <sqlite3.Row at 0x19d4f1b6dd0>,
#  <sqlite3.Row at 0x19d4f1b6e00>,
#  <sqlite3.Row at 0x19d4f1b6e30>,
#  <sqlite3.Row at 0x19d4f1b6e60>,
#  <sqlite3.Row at 0x19d4f1b6e90>,
#  <sqlite3.Row at 0x19d4f1b6ec0>,
#  <sqlite3.Row at 0x19d4f1b6ef0>,
#  <sqlite3.Row at 0x19d4f1b6f20>,
#  <sqlite3.Row at 0x19d4f1b6f50>,
#  <sqlite3.Row at 0x19d4f1b6f80>,
#  <sqlite3.Row at 0x19d4f1b6fb0>,
#  <sqlite3.Row at 0x19d4f1b6fe0>,
#  <sqlite3.Row at 0x19d4f1b7010>,
#  <sqlite3.Row at 0x19d4f1b7040>,
#  <sqlite3.Row at 0x19d4f1b7070>,
#  <sqlite3.Row at 0x19d4f1b70a0>,
#  <sqlite3.Row at 0x19d4f1b70d0>,
#  <sqlite3.Row at 0x19d4f1b7100>,
#  <sqlite3.Row at 0x19d4f1b7130>,
#  <sqlite3.Row at 0x19d4f1b7160>,
#  <sqlite3.Row at 0x19d4f1b7190>,
#  <sqlite3.Row at 0x19d4f1b71c0>,
#  <sqlite3.Row at 0x19d4f1b71f0>,
#  <sqlite3.Row at 0x19d4f1b7220>,
#  <sqlite3.Row at 0x19d4f1b7250>,
#  <sqlite3.Row at 0x19d4f1b7280>,
#  <sqlite3.Row at 0x19d4f1b72b0>,
#  <sqlite3.Row at 0x19d4f1b72e0>,
#  <sqlite3.Row at 0x19d4f1b7310>,
#  <sqlite3.Row at 0x19d4f1b7340>,
#  <sqlite3.Row at 0x19d4f1b7370>,
#  <sqlite3.Row at 0x19d4f1b73a0>,
#  <sqlite3.Row at 0x19d4f1b73d0>,
#  <sqlite3.Row at 0x19d4f1b7400>,
#  <sqlite3.Row at 0x19d4f1b7430>,
#  <sqlite3.Row at 0x19d4f1b7460>,
#  <sqlite3.Row at 0x19d4f1b7490>,
#  <sqlite3.Row at 0x19d4f1b74c0>,
#  <sqlite3.Row at 0x19d4f1b74f0>,
#  <sqlite3.Row at 0x19d4f1b7520>,
#  <sqlite3.Row at 0x19d4f1b7550>,
#  <sqlite3.Row at 0x19d4f1b7580>,
#  <sqlite3.Row at 0x19d4f1b75b0>,
#  <sqlite3.Row at 0x19d4f1b75e0>,
#  <sqlite3.Row at 0x19d4f1b7610>,
#  <sqlite3.Row at 0x19d4f1b7640>,
#  <sqlite3.Row at 0x19d4f1b7670>,
#  <sqlite3.Row at 0x19d4f1b76a0>,
#  <sqlite3.Row at 0x19d4f1b76d0>,
#  <sqlite3.Row at 0x19d4f1b7700>,
#  <sqlite3.Row at 0x19d4f1b7730>,
#  <sqlite3.Row at 0x19d4f1b7760>,
#  <sqlite3.Row at 0x19d4f1b7790>,
#  <sqlite3.Row at 0x19d4f1b77c0>,
#  <sqlite3.Row at 0x19d4f1b77f0>,
#  <sqlite3.Row at 0x19d4f1b7820>,
#  <sqlite3.Row at 0x19d4f1b7850>,
#  <sqlite3.Row at 0x19d4f1b7880>,
#  <sqlite3.Row at 0x19d4f1b78b0>,
#  <sqlite3.Row at 0x19d4f1b78e0>,
#  <sqlite3.Row at 0x19d4f1b7910>,
#  <sqlite3.Row at 0x19d4f1b7940>,
#  <sqlite3.Row at 0x19d4f1b7970>,
#  <sqlite3.Row at 0x19d4f1b79a0>,
#  <sqlite3.Row at 0x19d4f1b79d0>,
#  <sqlite3.Row at 0x19d4f1b7a00>,
#  <sqlite3.Row at 0x19d4f1b7a30>,
#  <sqlite3.Row at 0x19d4f1b7a60>,
#  <sqlite3.Row at 0x19d4f1b7a90>,
#  <sqlite3.Row at 0x19d4f1b7ac0>,
#  <sqlite3.Row at 0x19d4f1b7af0>,
#  <sqlite3.Row at 0x19d4f1b7b20>,
#  <sqlite3.Row at 0x19d4f1b7b50>,
#  <sqlite3.Row at 0x19d4f1b7b80>,
#  <sqlite3.Row at 0x19d4f1b7bb0>,
#  <sqlite3.Row at 0x19d4f1b7be0>,
#  <sqlite3.Row at 0x19d4f1b7c10>,
#  <sqlite3.Row at 0x19d4f1b7c40>,
#  <sqlite3.Row at 0x19d4f1b7c70>,
#  <sqlite3.Row at 0x19d4f1b7ca0>,
#  <sqlite3.Row at 0x19d4f1b7cd0>,
#  <sqlite3.Row at 0x19d4f1b7d00>,
#  <sqlite3.Row at 0x19d4f1b7d30>,
#  <sqlite3.Row at 0x19d4f1b7d60>,
#  <sqlite3.Row at 0x19d4f1b7d90>,
#  <sqlite3.Row at 0x19d4f1b7dc0>,
#  <sqlite3.Row at 0x19d4f1b7df0>,
#  <sqlite3.Row at 0x19d4f1b7e20>,
#  <sqlite3.Row at 0x19d4f1b7e50>,
#  <sqlite3.Row at 0x19d4f1b7e80>,
#  <sqlite3.Row at 0x19d4f1b7eb0>,
#  <sqlite3.Row at 0x19d4f1b7ee0>,
#  <sqlite3.Row at 0x19d4f1b7f10>,
#  <sqlite3.Row at 0x19d4f1b7f40>,
#  <sqlite3.Row at 0x19d4f1b7f70>,
#  <sqlite3.Row at 0x19d4f1b7fa0>,
#  <sqlite3.Row at 0x19d4f1b7fd0>,
#  <sqlite3.Row at 0x19d4f1f8040>,
#  <sqlite3.Row at 0x19d4f1f8070>,
#  <sqlite3.Row at 0x19d4f1f80a0>,
#  <sqlite3.Row at 0x19d4f1f80d0>,
#  <sqlite3.Row at 0x19d4f1f8100>,
#  <sqlite3.Row at 0x19d4f1f8130>,
#  <sqlite3.Row at 0x19d4f1f8160>,
#  <sqlite3.Row at 0x19d4f1f8190>,
#  <sqlite3.Row at 0x19d4f1f81c0>,
#  <sqlite3.Row at 0x19d4f1f81f0>,
#  <sqlite3.Row at 0x19d4f1f8220>,
#  <sqlite3.Row at 0x19d4f1f8250>,
#  <sqlite3.Row at 0x19d4f1f8280>,
#  <sqlite3.Row at 0x19d4f1f82b0>,
#  <sqlite3.Row at 0x19d4f1f82e0>,
#  <sqlite3.Row at 0x19d4f1f8310>,
#  <sqlite3.Row at 0x19d4f1f8340>,
#  <sqlite3.Row at 0x19d4f1f8370>,
#  <sqlite3.Row at 0x19d4f1f83a0>,
#  <sqlite3.Row at 0x19d4f1f83d0>,
#  <sqlite3.Row at 0x19d4f1f8400>,
#  <sqlite3.Row at 0x19d4f1f8430>,
#  <sqlite3.Row at 0x19d4f1f8460>,
#  <sqlite3.Row at 0x19d4f1f8490>,
#  <sqlite3.Row at 0x19d4f1f84c0>,
#  <sqlite3.Row at 0x19d4f1f84f0>,
#  <sqlite3.Row at 0x19d4f1f8520>,
#  <sqlite3.Row at 0x19d4f1f8550>,
#  <sqlite3.Row at 0x19d4f1f8580>,
#  <sqlite3.Row at 0x19d4f1f85b0>,
#  <sqlite3.Row at 0x19d4f1f85e0>,
#  <sqlite3.Row at 0x19d4f1f8610>,
#  <sqlite3.Row at 0x19d4f1f8640>,
#  <sqlite3.Row at 0x19d4f1f8670>,
#  <sqlite3.Row at 0x19d4f1f86a0>,
#  <sqlite3.Row at 0x19d4f1f86d0>,
#  <sqlite3.Row at 0x19d4f1f8700>,
#  <sqlite3.Row at 0x19d4f1f8730>,
#  <sqlite3.Row at 0x19d4f1f8760>,
#  <sqlite3.Row at 0x19d4f1f8790>,
#  <sqlite3.Row at 0x19d4f1f87c0>,
#  <sqlite3.Row at 0x19d4f1f87f0>,
#  <sqlite3.Row at 0x19d4f1f8820>,
#  <sqlite3.Row at 0x19d4f1f8850>,
#  <sqlite3.Row at 0x19d4f1f8880>,
#  <sqlite3.Row at 0x19d4f1f88b0>,
#  <sqlite3.Row at 0x19d4f1f88e0>,
#  <sqlite3.Row at 0x19d4f1f8910>,
#  <sqlite3.Row at 0x19d4f1f8940>,
#  <sqlite3.Row at 0x19d4f1f8970>,
#  <sqlite3.Row at 0x19d4f1f89a0>,
#  <sqlite3.Row at 0x19d4f1f89d0>,
#  <sqlite3.Row at 0x19d4f1f8a00>,
#  <sqlite3.Row at 0x19d4f1f8a30>,
#  <sqlite3.Row at 0x19d4f1f8a60>,
#  <sqlite3.Row at 0x19d4f1f8a90>,
#  <sqlite3.Row at 0x19d4f1f8ac0>,
#  <sqlite3.Row at 0x19d4f1f8af0>,
#  <sqlite3.Row at 0x19d4f1f8b20>,
#  <sqlite3.Row at 0x19d4f1f8b50>,
#  <sqlite3.Row at 0x19d4f1f8b80>,
#  <sqlite3.Row at 0x19d4f1f8bb0>,
#  <sqlite3.Row at 0x19d4f1f8be0>,
#  <sqlite3.Row at 0x19d4f1f8c10>,
#  <sqlite3.Row at 0x19d4f1f8c40>,
#  <sqlite3.Row at 0x19d4f1f8c70>,
#  <sqlite3.Row at 0x19d4f1f8ca0>,
#  <sqlite3.Row at 0x19d4f1f8cd0>,
#  <sqlite3.Row at 0x19d4f1f8d00>,
#  <sqlite3.Row at 0x19d4f1f8d30>,
#  <sqlite3.Row at 0x19d4f1f8d60>,
#  <sqlite3.Row at 0x19d4f1f8d90>,
#  <sqlite3.Row at 0x19d4f1f8dc0>,
#  <sqlite3.Row at 0x19d4f1f8df0>,
#  <sqlite3.Row at 0x19d4f1f8e20>,
#  <sqlite3.Row at 0x19d4f1f8e50>,
#  <sqlite3.Row at 0x19d4f1f8e80>,
#  <sqlite3.Row at 0x19d4f1f8eb0>,
#  <sqlite3.Row at 0x19d4f1f8ee0>,
#  <sqlite3.Row at 0x19d4f1f8f10>,
#  <sqlite3.Row at 0x19d4f1f8f40>,
#  <sqlite3.Row at 0x19d4f1f8f70>,
#  <sqlite3.Row at 0x19d4f1f8fa0>,
#  <sqlite3.Row at 0x19d4f1f8fd0>,
#  <sqlite3.Row at 0x19d4f1f9000>,
#  <sqlite3.Row at 0x19d4f1f9030>,
#  <sqlite3.Row at 0x19d4f1f9060>,
#  <sqlite3.Row at 0x19d4f1f9090>,
#  <sqlite3.Row at 0x19d4f1f90c0>,
#  <sqlite3.Row at 0x19d4f1f90f0>,
#  <sqlite3.Row at 0x19d4f1f9120>,
#  <sqlite3.Row at 0x19d4f1f9150>,
#  <sqlite3.Row at 0x19d4f1f9180>,
#  <sqlite3.Row at 0x19d4f1f91b0>,
#  <sqlite3.Row at 0x19d4f1f91e0>,
#  <sqlite3.Row at 0x19d4f1f9210>,
#  <sqlite3.Row at 0x19d4f1f9240>,
#  <sqlite3.Row at 0x19d4f1f9270>,
#  <sqlite3.Row at 0x19d4f1f92a0>,
#  <sqlite3.Row at 0x19d4f1f92d0>,
#  <sqlite3.Row at 0x19d4f1f9300>,
#  <sqlite3.Row at 0x19d4f1f9330>,
#  <sqlite3.Row at 0x19d4f1f9360>,
#  <sqlite3.Row at 0x19d4f1f9390>,
#  <sqlite3.Row at 0x19d4f1f93c0>,
#  <sqlite3.Row at 0x19d4f1f93f0>,
#  <sqlite3.Row at 0x19d4f1f9420>,
#  <sqlite3.Row at 0x19d4f1f9450>,
#  <sqlite3.Row at 0x19d4f1f9480>,
#  <sqlite3.Row at 0x19d4f1f94b0>,
#  <sqlite3.Row at 0x19d4f1f94e0>,
#  <sqlite3.Row at 0x19d4f1f9510>,
#  <sqlite3.Row at 0x19d4f1f9540>,
#  <sqlite3.Row at 0x19d4f1f9570>,
#  <sqlite3.Row at 0x19d4f1f95a0>,
#  <sqlite3.Row at 0x19d4f1f95d0>,
#  <sqlite3.Row at 0x19d4f1f9600>,
#  <sqlite3.Row at 0x19d4f1f9630>,
#  <sqlite3.Row at 0x19d4f1f9660>,
#  <sqlite3.Row at 0x19d4f1f9690>,
#  <sqlite3.Row at 0x19d4f1f96c0>,
#  <sqlite3.Row at 0x19d4f1f96f0>,
#  <sqlite3.Row at 0x19d4f1f9720>,
#  <sqlite3.Row at 0x19d4f1f9750>,
#  <sqlite3.Row at 0x19d4f1f9780>,
#  <sqlite3.Row at 0x19d4f1f97b0>,
#  <sqlite3.Row at 0x19d4f1f97e0>,
#  <sqlite3.Row at 0x19d4f1f9810>,
#  <sqlite3.Row at 0x19d4f1f9840>,
#  <sqlite3.Row at 0x19d4f1f9870>,
#  <sqlite3.Row at 0x19d4f1f98a0>,
#  <sqlite3.Row at 0x19d4f1f98d0>,
#  <sqlite3.Row at 0x19d4f1f9900>,
#  <sqlite3.Row at 0x19d4f1f9930>,
#  <sqlite3.Row at 0x19d4f1f9960>,
#  <sqlite3.Row at 0x19d4f1f9990>,
#  <sqlite3.Row at 0x19d4f1f99c0>,
#  <sqlite3.Row at 0x19d4f1f99f0>,
#  <sqlite3.Row at 0x19d4f1f9a20>,
#  <sqlite3.Row at 0x19d4f1f9a50>,
#  <sqlite3.Row at 0x19d4f1f9a80>,
#  <sqlite3.Row at 0x19d4f1f9ab0>,
#  <sqlite3.Row at 0x19d4f1f9ae0>,
#  <sqlite3.Row at 0x19d4f1f9b10>,
#  <sqlite3.Row at 0x19d4f1f9b40>,
#  <sqlite3.Row at 0x19d4f1f9b70>,
#  <sqlite3.Row at 0x19d4f1f9ba0>,
#  <sqlite3.Row at 0x19d4f1f9bd0>,
#  <sqlite3.Row at 0x19d4f1f9c00>,
#  <sqlite3.Row at 0x19d4f1f9c30>,
#  <sqlite3.Row at 0x19d4f1f9c60>,
#  <sqlite3.Row at 0x19d4f1f9c90>,
#  <sqlite3.Row at 0x19d4f1f9cc0>,
#  <sqlite3.Row at 0x19d4f1f9cf0>,
#  <sqlite3.Row at 0x19d4f1f9d20>,
#  <sqlite3.Row at 0x19d4f1f9d50>,
#  <sqlite3.Row at 0x19d4f1f9d80>,
#  <sqlite3.Row at 0x19d4f1f9db0>,
#  <sqlite3.Row at 0x19d4f1f9de0>,
#  <sqlite3.Row at 0x19d4f1f9e10>,
#  <sqlite3.Row at 0x19d4f1f9e40>,
#  <sqlite3.Row at 0x19d4f1f9e70>,
#  <sqlite3.Row at 0x19d4f1f9ea0>,
#  <sqlite3.Row at 0x19d4f1f9ed0>,
#  <sqlite3.Row at 0x19d4f1f9f00>,
#  <sqlite3.Row at 0x19d4f1f9f30>,
#  <sqlite3.Row at 0x19d4f1f9f60>,
#  <sqlite3.Row at 0x19d4f1f9f90>,
#  <sqlite3.Row at 0x19d4f1f9fc0>,
#  <sqlite3.Row at 0x19d4f1f9ff0>,
#  <sqlite3.Row at 0x19d4f1fa020>,
#  <sqlite3.Row at 0x19d4f1fa050>,
#  <sqlite3.Row at 0x19d4f1fa080>,
#  <sqlite3.Row at 0x19d4f1fa0b0>,
#  <sqlite3.Row at 0x19d4f1fa0e0>,
#  <sqlite3.Row at 0x19d4f1fa110>,
#  <sqlite3.Row at 0x19d4f1fa140>,
#  <sqlite3.Row at 0x19d4f1fa170>,
#  <sqlite3.Row at 0x19d4f1fa1a0>,
#  <sqlite3.Row at 0x19d4f1fa1d0>,
#  <sqlite3.Row at 0x19d4f1fa200>,
#  <sqlite3.Row at 0x19d4f1fa230>,
#  <sqlite3.Row at 0x19d4f1fa260>,
#  <sqlite3.Row at 0x19d4f1fa290>,
#  <sqlite3.Row at 0x19d4f1fa2c0>,
#  <sqlite3.Row at 0x19d4f1fa2f0>,
#  <sqlite3.Row at 0x19d4f1fa320>,
#  <sqlite3.Row at 0x19d4f1fa350>,
#  <sqlite3.Row at 0x19d4f1fa380>,
#  <sqlite3.Row at 0x19d4f1fa3b0>,
#  <sqlite3.Row at 0x19d4f1fa3e0>,
#  <sqlite3.Row at 0x19d4f1fa410>,
#  <sqlite3.Row at 0x19d4f1fa440>,
#  <sqlite3.Row at 0x19d4f1fa470>,
#  <sqlite3.Row at 0x19d4f1fa4a0>,
#  <sqlite3.Row at 0x19d4f1fa4d0>,
#  <sqlite3.Row at 0x19d4f1fa500>,
#  <sqlite3.Row at 0x19d4f1fa530>,
#  <sqlite3.Row at 0x19d4f1fa560>,
#  <sqlite3.Row at 0x19d4f1fa590>,
#  <sqlite3.Row at 0x19d4f1fa5c0>,
#  <sqlite3.Row at 0x19d4f1fa5f0>,
#  <sqlite3.Row at 0x19d4f1fa620>,
#  <sqlite3.Row at 0x19d4f1fa650>,
#  <sqlite3.Row at 0x19d4f1fa680>,
#  <sqlite3.Row at 0x19d4f1fa6b0>,
#  <sqlite3.Row at 0x19d4f1fa6e0>,
#  <sqlite3.Row at 0x19d4f1fa710>,
#  <sqlite3.Row at 0x19d4f1fa740>,
#  <sqlite3.Row at 0x19d4f1fa770>,
#  <sqlite3.Row at 0x19d4f1fa7a0>,
#  <sqlite3.Row at 0x19d4f1fa7d0>,
#  <sqlite3.Row at 0x19d4f1fa800>,
#  <sqlite3.Row at 0x19d4f1fa830>,
#  <sqlite3.Row at 0x19d4f1fa860>,
#  <sqlite3.Row at 0x19d4f1fa890>,
#  <sqlite3.Row at 0x19d4f1fa8c0>,
#  <sqlite3.Row at 0x19d4f1fa8f0>,
#  <sqlite3.Row at 0x19d4f1fa920>,
#  <sqlite3.Row at 0x19d4f1fa950>,
#  <sqlite3.Row at 0x19d4f1fa980>,
#  <sqlite3.Row at 0x19d4f1fa9b0>,
#  <sqlite3.Row at 0x19d4f1fa9e0>,
#  <sqlite3.Row at 0x19d4f1faa10>,
#  <sqlite3.Row at 0x19d4f1faa40>,
#  <sqlite3.Row at 0x19d4f1faa70>,
#  <sqlite3.Row at 0x19d4f1faaa0>,
#  <sqlite3.Row at 0x19d4f1faad0>,
#  <sqlite3.Row at 0x19d4f1fab00>,
#  <sqlite3.Row at 0x19d4f1fab30>,
#  <sqlite3.Row at 0x19d4f1fab60>,
#  <sqlite3.Row at 0x19d4f1fab90>,
#  <sqlite3.Row at 0x19d4f1fabc0>,
#  <sqlite3.Row at 0x19d4f1fabf0>,
#  <sqlite3.Row at 0x19d4f1fac20>,
#  <sqlite3.Row at 0x19d4f1fac50>,
#  <sqlite3.Row at 0x19d4f1fac80>,
#  <sqlite3.Row at 0x19d4f1facb0>,
#  <sqlite3.Row at 0x19d4f1face0>,
#  <sqlite3.Row at 0x19d4f1fad10>,
#  <sqlite3.Row at 0x19d4f1fad40>,
#  <sqlite3.Row at 0x19d4f1fad70>,
#  <sqlite3.Row at 0x19d4f1fada0>,
#  <sqlite3.Row at 0x19d4f1fadd0>,
#  <sqlite3.Row at 0x19d4f1fae00>,
#  <sqlite3.Row at 0x19d4f1fae30>,
#  <sqlite3.Row at 0x19d4f1fae60>,
#  <sqlite3.Row at 0x19d4f1fae90>,
#  <sqlite3.Row at 0x19d4f1faec0>,
#  <sqlite3.Row at 0x19d4f1faef0>,
#  <sqlite3.Row at 0x19d4f1faf20>,
#  <sqlite3.Row at 0x19d4f1faf50>,
#  <sqlite3.Row at 0x19d4f1faf80>,
#  <sqlite3.Row at 0x19d4f1fafb0>,
#  <sqlite3.Row at 0x19d4f1fafe0>,
#  <sqlite3.Row at 0x19d4f1fb010>,
#  <sqlite3.Row at 0x19d4f1fb040>,
#  <sqlite3.Row at 0x19d4f1fb070>,
#  <sqlite3.Row at 0x19d4f1fb0a0>,
#  <sqlite3.Row at 0x19d4f1fb0d0>,
#  <sqlite3.Row at 0x19d4f1fb100>,
#  <sqlite3.Row at 0x19d4f1fb130>,
#  <sqlite3.Row at 0x19d4f1fb160>,
#  <sqlite3.Row at 0x19d4f1fb190>,
#  <sqlite3.Row at 0x19d4f1fb1c0>,
#  <sqlite3.Row at 0x19d4f1fb1f0>,
#  <sqlite3.Row at 0x19d4f1fb220>,
#  <sqlite3.Row at 0x19d4f1fb250>,
#  <sqlite3.Row at 0x19d4f1fb280>,
#  <sqlite3.Row at 0x19d4f1fb2b0>,
#  <sqlite3.Row at 0x19d4f1fb2e0>,
#  <sqlite3.Row at 0x19d4f1fb310>,
#  <sqlite3.Row at 0x19d4f1fb340>,
#  <sqlite3.Row at 0x19d4f1fb370>,
#  <sqlite3.Row at 0x19d4f1fb3a0>,
#  <sqlite3.Row at 0x19d4f1fb3d0>,
#  <sqlite3.Row at 0x19d4f1fb400>,
#  <sqlite3.Row at 0x19d4f1fb430>,
#  <sqlite3.Row at 0x19d4f1fb460>,
#  <sqlite3.Row at 0x19d4f1fb490>,
#  <sqlite3.Row at 0x19d4f1fb4c0>,
#  <sqlite3.Row at 0x19d4f1fb4f0>,
#  <sqlite3.Row at 0x19d4f1fb520>,
#  <sqlite3.Row at 0x19d4f1fb550>,
#  <sqlite3.Row at 0x19d4f1fb580>,
#  <sqlite3.Row at 0x19d4f1fb5b0>,
#  <sqlite3.Row at 0x19d4f1fb5e0>,
#  <sqlite3.Row at 0x19d4f1fb610>,
#  <sqlite3.Row at 0x19d4f1fb640>,
#  <sqlite3.Row at 0x19d4f1fb670>,
#  <sqlite3.Row at 0x19d4f1fb6a0>,
#  <sqlite3.Row at 0x19d4f1fb6d0>,
#  <sqlite3.Row at 0x19d4f1fb700>,
#  <sqlite3.Row at 0x19d4f1fb730>,
#  <sqlite3.Row at 0x19d4f1fb760>,
#  <sqlite3.Row at 0x19d4f1fb790>,
#  <sqlite3.Row at 0x19d4f1fb7c0>,
#  <sqlite3.Row at 0x19d4f1fb7f0>,
#  <sqlite3.Row at 0x19d4f1fb820>,
#  <sqlite3.Row at 0x19d4f1fb850>,
#  <sqlite3.Row at 0x19d4f1fb880>,
#  <sqlite3.Row at 0x19d4f1fb8b0>,
#  <sqlite3.Row at 0x19d4f1fb8e0>,
#  <sqlite3.Row at 0x19d4f1fb910>,
#  <sqlite3.Row at 0x19d4f1fb940>,
#  <sqlite3.Row at 0x19d4f1fb970>,
#  <sqlite3.Row at 0x19d4f1fb9a0>,
#  <sqlite3.Row at 0x19d4f1fb9d0>,
#  <sqlite3.Row at 0x19d4f1fba00>,
#  <sqlite3.Row at 0x19d4f1fba30>,
#  <sqlite3.Row at 0x19d4f1fba60>,
#  <sqlite3.Row at 0x19d4f1fba90>,
#  <sqlite3.Row at 0x19d4f1fbac0>,
#  <sqlite3.Row at 0x19d4f1fbaf0>,
#  <sqlite3.Row at 0x19d4f1fbb20>,
#  <sqlite3.Row at 0x19d4f1fbb50>,
#  <sqlite3.Row at 0x19d4f1fbb80>,
#  <sqlite3.Row at 0x19d4f1fbbb0>,
#  <sqlite3.Row at 0x19d4f1fbbe0>,
#  <sqlite3.Row at 0x19d4f1fbc10>,
#  <sqlite3.Row at 0x19d4f1fbc40>,
#  <sqlite3.Row at 0x19d4f1fbc70>,
#  <sqlite3.Row at 0x19d4f1fbca0>,
#  <sqlite3.Row at 0x19d4f1fbcd0>,
#  <sqlite3.Row at 0x19d4f1fbd00>,
#  <sqlite3.Row at 0x19d4f1fbd30>,
#  <sqlite3.Row at 0x19d4f1fbd60>,
#  <sqlite3.Row at 0x19d4f1fbd90>,
#  <sqlite3.Row at 0x19d4f1fbdc0>,
#  <sqlite3.Row at 0x19d4f1fbdf0>,
#  <sqlite3.Row at 0x19d4f1fbe20>,
#  <sqlite3.Row at 0x19d4f1fbe50>,
#  <sqlite3.Row at 0x19d4f1fbe80>,
#  <sqlite3.Row at 0x19d4f1fbeb0>,
#  <sqlite3.Row at 0x19d4f1fbee0>,
#  <sqlite3.Row at 0x19d4f1fbf10>,
#  <sqlite3.Row at 0x19d4f1fbf40>,
#  <sqlite3.Row at 0x19d4f1fbf70>,
#  <sqlite3.Row at 0x19d4f1fbfa0>,
#  <sqlite3.Row at 0x19d4f1fbfd0>,
#  <sqlite3.Row at 0x19d4f238040>,
#  <sqlite3.Row at 0x19d4f238070>,
#  <sqlite3.Row at 0x19d4f2380a0>,
#  <sqlite3.Row at 0x19d4f2380d0>,
#  <sqlite3.Row at 0x19d4f238100>,
#  <sqlite3.Row at 0x19d4f238130>,
#  <sqlite3.Row at 0x19d4f238160>,
#  <sqlite3.Row at 0x19d4f238190>,
#  <sqlite3.Row at 0x19d4f2381c0>,
#  <sqlite3.Row at 0x19d4f2381f0>,
#  <sqlite3.Row at 0x19d4f238220>,
#  <sqlite3.Row at 0x19d4f238250>,
#  <sqlite3.Row at 0x19d4f238280>,
#  <sqlite3.Row at 0x19d4f2382b0>,
#  <sqlite3.Row at 0x19d4f2382e0>,
#  <sqlite3.Row at 0x19d4f238310>,
#  <sqlite3.Row at 0x19d4f238340>,
#  <sqlite3.Row at 0x19d4f238370>,
#  <sqlite3.Row at 0x19d4f2383a0>,
#  <sqlite3.Row at 0x19d4f2383d0>,
#  <sqlite3.Row at 0x19d4f238400>,
#  <sqlite3.Row at 0x19d4f238430>,
#  <sqlite3.Row at 0x19d4f238460>,
#  <sqlite3.Row at 0x19d4f238490>,
#  <sqlite3.Row at 0x19d4f2384c0>,
#  <sqlite3.Row at 0x19d4f2384f0>,
#  <sqlite3.Row at 0x19d4f238520>,
#  <sqlite3.Row at 0x19d4f238550>,
#  <sqlite3.Row at 0x19d4f238580>,
#  <sqlite3.Row at 0x19d4f2385b0>,
#  <sqlite3.Row at 0x19d4f2385e0>,
#  <sqlite3.Row at 0x19d4f238610>,
#  <sqlite3.Row at 0x19d4f238640>,
#  <sqlite3.Row at 0x19d4f238670>,
#  <sqlite3.Row at 0x19d4f2386a0>,
#  <sqlite3.Row at 0x19d4f2386d0>,
#  <sqlite3.Row at 0x19d4f238700>,
#  <sqlite3.Row at 0x19d4f238730>,
#  <sqlite3.Row at 0x19d4f238760>,
#  <sqlite3.Row at 0x19d4f238790>,
#  <sqlite3.Row at 0x19d4f2387c0>,
#  <sqlite3.Row at 0x19d4f2387f0>,
#  <sqlite3.Row at 0x19d4f238820>,
#  <sqlite3.Row at 0x19d4f238850>,
#  <sqlite3.Row at 0x19d4f238880>,
#  <sqlite3.Row at 0x19d4f2388b0>,
#  <sqlite3.Row at 0x19d4f2388e0>,
#  <sqlite3.Row at 0x19d4f238910>,
#  <sqlite3.Row at 0x19d4f238940>,
#  <sqlite3.Row at 0x19d4f238970>,
#  <sqlite3.Row at 0x19d4f2389a0>,
#  <sqlite3.Row at 0x19d4f2389d0>,
#  <sqlite3.Row at 0x19d4f238a00>,
#  <sqlite3.Row at 0x19d4f238a30>,
#  <sqlite3.Row at 0x19d4f238a60>,
#  <sqlite3.Row at 0x19d4f238a90>,
#  <sqlite3.Row at 0x19d4f238ac0>,
#  <sqlite3.Row at 0x19d4f238af0>,
#  <sqlite3.Row at 0x19d4f238b20>,
#  <sqlite3.Row at 0x19d4f238b50>,
#  <sqlite3.Row at 0x19d4f238b80>,
#  <sqlite3.Row at 0x19d4f238bb0>,
#  <sqlite3.Row at 0x19d4f238be0>,
#  <sqlite3.Row at 0x19d4f238c10>,
#  <sqlite3.Row at 0x19d4f238c40>,
#  <sqlite3.Row at 0x19d4f238c70>,
#  <sqlite3.Row at 0x19d4f238ca0>,
#  <sqlite3.Row at 0x19d4f238cd0>,
#  <sqlite3.Row at 0x19d4f238d00>,
#  <sqlite3.Row at 0x19d4f238d30>,
#  <sqlite3.Row at 0x19d4f238d60>,
#  <sqlite3.Row at 0x19d4f238d90>,
#  <sqlite3.Row at 0x19d4f238dc0>,
#  <sqlite3.Row at 0x19d4f238df0>,
#  <sqlite3.Row at 0x19d4f238e20>,
#  <sqlite3.Row at 0x19d4f238e50>,
#  <sqlite3.Row at 0x19d4f238e80>,
#  <sqlite3.Row at 0x19d4f238eb0>,
#  <sqlite3.Row at 0x19d4f238ee0>,
#  <sqlite3.Row at 0x19d4f238f10>,
#  <sqlite3.Row at 0x19d4f238f40>,
#  <sqlite3.Row at 0x19d4f238f70>,
#  <sqlite3.Row at 0x19d4f238fa0>,
#  <sqlite3.Row at 0x19d4f238fd0>,
#  <sqlite3.Row at 0x19d4f239000>,
#  <sqlite3.Row at 0x19d4f239030>,
#  <sqlite3.Row at 0x19d4f239060>,
#  <sqlite3.Row at 0x19d4f239090>,
#  <sqlite3.Row at 0x19d4f2390c0>,
#  <sqlite3.Row at 0x19d4f2390f0>,
#  <sqlite3.Row at 0x19d4f239120>,
#  <sqlite3.Row at 0x19d4f239150>,
#  <sqlite3.Row at 0x19d4f239180>,
#  <sqlite3.Row at 0x19d4f2391b0>,
#  <sqlite3.Row at 0x19d4f2391e0>,
#  <sqlite3.Row at 0x19d4f239210>,
#  <sqlite3.Row at 0x19d4f239240>,
#  <sqlite3.Row at 0x19d4f239270>,
#  <sqlite3.Row at 0x19d4f2392a0>,
#  <sqlite3.Row at 0x19d4f2392d0>,
#  <sqlite3.Row at 0x19d4f239300>,
#  <sqlite3.Row at 0x19d4f239330>,
#  <sqlite3.Row at 0x19d4f239360>,
#  <sqlite3.Row at 0x19d4f239390>,
#  <sqlite3.Row at 0x19d4f2393c0>,
#  <sqlite3.Row at 0x19d4f2393f0>,
#  <sqlite3.Row at 0x19d4f239420>,
#  <sqlite3.Row at 0x19d4f239450>,
#  <sqlite3.Row at 0x19d4f239480>,
#  <sqlite3.Row at 0x19d4f2394b0>,
#  <sqlite3.Row at 0x19d4f2394e0>,
#  <sqlite3.Row at 0x19d4f239510>,
#  <sqlite3.Row at 0x19d4f239540>,
#  <sqlite3.Row at 0x19d4f239570>,
#  <sqlite3.Row at 0x19d4f2395a0>,
#  <sqlite3.Row at 0x19d4f2395d0>,
#  <sqlite3.Row at 0x19d4f239600>,
#  <sqlite3.Row at 0x19d4f239630>,
#  <sqlite3.Row at 0x19d4f239660>,
#  <sqlite3.Row at 0x19d4f239690>,
#  <sqlite3.Row at 0x19d4f2396c0>,
#  <sqlite3.Row at 0x19d4f2396f0>,
#  <sqlite3.Row at 0x19d4f239720>,
#  <sqlite3.Row at 0x19d4f239750>,
#  <sqlite3.Row at 0x19d4f239780>,
#  <sqlite3.Row at 0x19d4f2397b0>,
#  <sqlite3.Row at 0x19d4f2397e0>,
#  <sqlite3.Row at 0x19d4f239810>,
#  <sqlite3.Row at 0x19d4f239840>,
#  <sqlite3.Row at 0x19d4f239870>,
#  <sqlite3.Row at 0x19d4f2398a0>,
#  <sqlite3.Row at 0x19d4f2398d0>,
#  <sqlite3.Row at 0x19d4f239900>,
#  <sqlite3.Row at 0x19d4f239930>,
#  <sqlite3.Row at 0x19d4f239960>,
#  <sqlite3.Row at 0x19d4f239990>,
#  <sqlite3.Row at 0x19d4f2399c0>,
#  <sqlite3.Row at 0x19d4f2399f0>,
#  <sqlite3.Row at 0x19d4f239a20>,
#  <sqlite3.Row at 0x19d4f239a50>,
#  <sqlite3.Row at 0x19d4f239a80>,
#  <sqlite3.Row at 0x19d4f239ab0>,
#  <sqlite3.Row at 0x19d4f239ae0>,
#  <sqlite3.Row at 0x19d4f239b10>,
#  <sqlite3.Row at 0x19d4f239b40>,
#  <sqlite3.Row at 0x19d4f239b70>,
#  <sqlite3.Row at 0x19d4f239ba0>,
#  <sqlite3.Row at 0x19d4f239bd0>,
#  <sqlite3.Row at 0x19d4f239c00>,
#  <sqlite3.Row at 0x19d4f239c30>,
#  <sqlite3.Row at 0x19d4f239c60>,
#  <sqlite3.Row at 0x19d4f239c90>,
#  <sqlite3.Row at 0x19d4f239cc0>,
#  <sqlite3.Row at 0x19d4f239cf0>,
#  <sqlite3.Row at 0x19d4f239d20>,
#  <sqlite3.Row at 0x19d4f239d50>,
#  <sqlite3.Row at 0x19d4f239d80>,
#  <sqlite3.Row at 0x19d4f239db0>,
#  <sqlite3.Row at 0x19d4f239de0>,
#  <sqlite3.Row at 0x19d4f239e10>,
#  <sqlite3.Row at 0x19d4f239e40>,
#  <sqlite3.Row at 0x19d4f239e70>,
#  <sqlite3.Row at 0x19d4f239ea0>,
#  <sqlite3.Row at 0x19d4f239ed0>,
#  <sqlite3.Row at 0x19d4f239f00>,
#  <sqlite3.Row at 0x19d4f239f30>,
#  <sqlite3.Row at 0x19d4f239f60>,
#  <sqlite3.Row at 0x19d4f239f90>,
#  <sqlite3.Row at 0x19d4f239fc0>,
#  <sqlite3.Row at 0x19d4f239ff0>,
#  <sqlite3.Row at 0x19d4f23a020>,
#  <sqlite3.Row at 0x19d4f23a050>,
#  <sqlite3.Row at 0x19d4f23a080>,
#  <sqlite3.Row at 0x19d4f23a0b0>,
#  <sqlite3.Row at 0x19d4f23a0e0>,
#  <sqlite3.Row at 0x19d4f23a110>,
#  <sqlite3.Row at 0x19d4f23a140>,
#  <sqlite3.Row at 0x19d4f23a170>,
#  <sqlite3.Row at 0x19d4f23a1a0>,
#  <sqlite3.Row at 0x19d4f23a1d0>,
#  <sqlite3.Row at 0x19d4f23a200>,
#  <sqlite3.Row at 0x19d4f23a230>,
#  <sqlite3.Row at 0x19d4f23a260>,
#  <sqlite3.Row at 0x19d4f23a290>,
#  <sqlite3.Row at 0x19d4f23a2c0>,
#  <sqlite3.Row at 0x19d4f23a2f0>,
#  <sqlite3.Row at 0x19d4f23a320>,
#  <sqlite3.Row at 0x19d4f23a350>,
#  <sqlite3.Row at 0x19d4f23a380>,
#  <sqlite3.Row at 0x19d4f23a3b0>,
#  <sqlite3.Row at 0x19d4f23a3e0>,
#  <sqlite3.Row at 0x19d4f23a410>,
#  <sqlite3.Row at 0x19d4f23a440>,
#  <sqlite3.Row at 0x19d4f23a470>,
#  <sqlite3.Row at 0x19d4f23a4a0>,
#  <sqlite3.Row at 0x19d4f23a4d0>,
#  <sqlite3.Row at 0x19d4f23a500>,
#  <sqlite3.Row at 0x19d4f23a530>,
#  <sqlite3.Row at 0x19d4f23a560>,
#  <sqlite3.Row at 0x19d4f23a590>,
#  <sqlite3.Row at 0x19d4f23a5c0>,
#  <sqlite3.Row at 0x19d4f23a5f0>,
#  <sqlite3.Row at 0x19d4f23a620>,
#  <sqlite3.Row at 0x19d4f23a650>,
#  <sqlite3.Row at 0x19d4f23a680>,
#  <sqlite3.Row at 0x19d4f23a6b0>,
#  <sqlite3.Row at 0x19d4f23a6e0>,
#  <sqlite3.Row at 0x19d4f23a710>,
#  <sqlite3.Row at 0x19d4f23a740>,
#  <sqlite3.Row at 0x19d4f23a770>,
#  <sqlite3.Row at 0x19d4f23a7a0>,
#  <sqlite3.Row at 0x19d4f23a7d0>,
#  <sqlite3.Row at 0x19d4f23a800>,
#  <sqlite3.Row at 0x19d4f23a830>,
#  <sqlite3.Row at 0x19d4f23a860>,
#  <sqlite3.Row at 0x19d4f23a890>,
#  <sqlite3.Row at 0x19d4f23a8c0>,
#  <sqlite3.Row at 0x19d4f23a8f0>,
#  <sqlite3.Row at 0x19d4f23a920>,
#  <sqlite3.Row at 0x19d4f23a950>,
#  <sqlite3.Row at 0x19d4f23a980>,
#  <sqlite3.Row at 0x19d4f23a9b0>,
#  <sqlite3.Row at 0x19d4f23a9e0>,
#  <sqlite3.Row at 0x19d4f23aa10>,
#  <sqlite3.Row at 0x19d4f23aa40>,
#  <sqlite3.Row at 0x19d4f23aa70>,
#  <sqlite3.Row at 0x19d4f23aaa0>,
#  <sqlite3.Row at 0x19d4f23aad0>,
#  <sqlite3.Row at 0x19d4f23ab00>,
#  <sqlite3.Row at 0x19d4f23ab30>,
#  <sqlite3.Row at 0x19d4f23ab60>,
#  <sqlite3.Row at 0x19d4f23ab90>,
#  <sqlite3.Row at 0x19d4f23abc0>,
#  <sqlite3.Row at 0x19d4f23abf0>,
#  ...]

# %%
cur = con.cursor()

# %%
res = cur.execute('SELECT * FROM covid_cases;')

# %%
res.fetchone()
# Out:
# ('Alabama',
#  32.3182,
#  -86.9023,
#  1171,
#  7440,
#  18525,
#  39647,
#  90299,
#  127234,
#  155727,
#  194458,
#  252900,
#  365747,
#  460860,
#  493769,
#  515866,
#  528309,
#  544045,
#  550983,
#  587405,
#  704420,
#  798320,
#  832264,
#  846297,
#  896614,
#  1223896,
#  1280351,
#  1295353,
#  1300733,
#  1315934,
#  1359051,
#  1424411,
#  1494300,
#  1522135,
#  1534287,
#  1549285,
#  1568934,
#  1617850,
#  1642062)

# %%
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///data.sqlite")

Base = automap_base()

Base.prepare(autoload_with=engine)

# %%
Base.classes.keys()
# Out:
# []
